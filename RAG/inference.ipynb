# %%
import pandas as pd

# %%
df = pd.read_csv("/home/infidea/rebirth-hjun/KRAG_2025_2/KRAG_2025/0715_kanana-1.5-8b-instruct-2505_generated_queries_train_dev_test.csv")
df.head()
# Out:
#    id                                           question  \
# 0   1  "우동이 {불을/불} 것 같아 걱정이다." 가운데 올바른 것을 선택하고, 그 이유를...
# 1   2  다음 문장에서 어문 규범에 부합하지 않는 부분을 찾아 고치고, 그 이유를 설명하세요...
# 2   3  "묘비는 1670년 현종 11년에 후손인 김려와 언양 현감이 세웠다."를 올바르게 ...
# 3   4  다음 문장에서 어문 규범에 부합하지 않는 부분을 찾아 고치고, 그 이유를 설명하세요...
# 4   5  "{외출 시에는/외출시에는} 에어컨을 꼭 끕시다." 가운데 올바른 것을 선택하고, ...
#
#                                      expected_output  \
# 0  {'answer': '"우동이 불을 것 같아 걱정이다."가 옳다. \'붇다\'의 어...
# 1  {'answer': '"또한 갸름한 얼굴에 초승달 같은 눈썹, 가늘고 긴 눈, 오뚝...
# 2  {'answer': '"묘비는 현종 11년(1670년)에 후손인 김려와 언양 현감이...
# 3  {'answer': '"저장할까요 또는 취소할까요?"가 옳다. 한 문장 안에 몇 개...
# 4  {'answer': '"외출 시에는 에어컨을 꼭 끕시다."가 옳다. 여기서의 \'시...
#
#                       generated_queries
# 0                 ["부사 불 불이 아님 부사격 조사"]
# 1  ["의존명사 이목구비 한글맞춤법 오똑한 오똑한 코 표준어 규정"]
# 2                  ["묘비 건립 시기 표현 어문규정"]
# 3              ["저장할까요 취소할까요 맞춤법 어문규정"]
# 4               ["조사 생략 가능 여부 에어컨 명사구"]

# %%
df['generated_queries'][0]
# Out:
# '["부사 불 불이 아님 부사격 조사"]'

# %%
cleaned_str = df['generated_queries'][0].replace('[', '').replace('"', '').replace(']', '')

# %%
cleaned_str
# Out:
# '부사 불 불이 아님 부사격 조사'

# %%
import torch
import pandas as pd
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
import os

# --- 1. 기본 설정 ---
# 검색할 .txt 파일이 있는 디렉토리
DATA_PATH = "/home/infidea/rebirth-hjun/KRAG_2025/pre"
# 임베딩 모델 (다국어 지원 모델)
EMBEDDING_MODEL = "nlpai-lab/KURE-v1"
# 원본 쿼리 CSV 파일 경로
QUERY_CSV_PATH = "/home/infidea/rebirth-hjun/KRAG_2025_2/KRAG_2025/RAG/0715_kanana-1.5-8b-instruct-2505_generated_queries_train_dev_test.csv"
# 결과를 저장할 CSV 파일 경로
OUTPUT_CSV_PATH = "0715-retrieval_results.csv"

def main():
    # --- 사전 준비: 문서 로딩, 분할, 벡터 저장소 생성 (최초 1회만 실행) ---
    print("--- 2. 문서 로딩 및 분할 시작 ---")
    # 지정된 디렉토리에서 .txt 파일 로드
    loader = DirectoryLoader(
        DATA_PATH,
        glob="**/*.txt",
        loader_cls=TextLoader,
        loader_kwargs={'autodetect_encoding': True} # 인코딩 자동 감지
    )
    documents = loader.load()

    if not documents:
        print(f"오류: '{DATA_PATH}' 디렉토리에서 문서를 찾을 수 없습니다. .txt 파일이 있는지 확인하세요.")
        return

    # 텍스트를 작은 조각으로 분할
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=250, # 분할할 청크 크기
        chunk_overlap=25  # 청크 간 중첩 크기
    )
    texts = text_splitter.split_documents(documents)
    print(f"총 {len(documents)}개의 문서를 {len(texts)}개의 텍스트 조각으로 분할했습니다.")
    print("--- 문서 로딩 및 분할 완료 ---")

    print("\n--- 3. 임베딩 및 벡터 저장소 생성 시작 ---")
    # Hugging Face의 임베딩 모델 로드
    model_kwargs = {'device': 'cuda' if torch.cuda.is_available() else 'cpu'}
    encode_kwargs = {'normalize_embeddings': True}
    embeddings = HuggingFaceEmbeddings(
        model_name=EMBEDDING_MODEL,
        model_kwargs=model_kwargs,
        encode_kwargs=encode_kwargs
    )

    # FAISS 벡터 저장소 생성
    vectorstore = FAISS.from_documents(texts, embeddings)
    print("--- 임베딩 및 벡터 저장소 생성 완료 ---")

    print("\n--- 4. Retriever 생성 시작 ---")
    # 벡터 저장소를 retriever로 사용 (상위 1개 문서 검색)
    retriever = vectorstore.as_retriever(search_kwargs={'k': 1})
    print("--- Retriever 생성 완료 ---")

    # --- 5. 쿼리별 문서 검색 및 결과 저장 ---
    print("\n--- 5. 질문 및 문서 검색 시작 ---")
    df = pd.read_csv(QUERY_CSV_PATH)
    
    # 쿼리 전처리 (대괄호, 따옴표 제거)
    queries = [str(q).replace('[', '').replace('"', '').replace(']', '') for q in df['generated_queries']]
    
    retrieved_contents = [] # 검색된 내용을 저장할 리스트

    # 각 쿼리에 대해 문서 검색 실행
    for i, query in enumerate(queries):
        print(f"({i+1}/{len(queries)}) 쿼리 검색 중: {query}")
        
        # retriever를 직접 사용하여 관련 문서 검색
        retrieved_docs = retriever.get_relevant_documents(query)

        if retrieved_docs:
            # 검색된 문서가 있으면 page_content를 리스트에 추가
            content = retrieved_docs[0].page_content
            retrieved_contents.append(content)
        else:
            # 검색된 문서가 없으면 빈 문자열 또는 표시 문자 추가
            retrieved_contents.append("검색된 문서 없음")

    # --- 6. 결과를 DataFrame에 추가하고 파일로 저장 ---
    print("\n--- 6. 검색 결과 취합 및 저장 시작 ---")
    # 검색된 내용을 새로운 컬럼으로 DataFrame에 추가
    df['retrieved_content'] = retrieved_contents

    # 수정된 DataFrame을 새로운 CSV 파일로 저장
    # encoding='utf-8-sig'는 Excel에서 한글이 깨지지 않게 하기 위함
    df.to_csv(OUTPUT_CSV_PATH, index=False, encoding='utf-8-sig')
    print(f"모든 검색이 완료되었으며, 결과가 '{OUTPUT_CSV_PATH}' 파일에 저장되었습니다.")
    
    # 결과 확인 (상위 5개 행 출력)
    print("\n--- 최종 결과 (상위 5개) ---")
    print(df.head())


if __name__ == '__main__':
    main()
# Out:
# --- 2. 문서 로딩 및 분할 시작 ---
# 총 1개의 문서를 214개의 텍스트 조각으로 분할했습니다.
# --- 문서 로딩 및 분할 완료 ---
#
# --- 3. 임베딩 및 벡터 저장소 생성 시작 ---
# /tmp/ipykernel_2987940/2842773583.py:48: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# --- 임베딩 및 벡터 저장소 생성 완료 ---
#
# --- 4. Retriever 생성 시작 ---
# --- Retriever 생성 완료 ---
#
# --- 5. 질문 및 문서 검색 시작 ---
# (1/1247) 쿼리 검색 중: 부사 불 불이 아님 부사격 조사
# /tmp/ipykernel_2987940/2842773583.py:77: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   retrieved_docs = retriever.get_relevant_documents(query)
# (2/1247) 쿼리 검색 중: 의존명사 이목구비 한글맞춤법 오똑한 오똑한 코 표준어 규정
# (3/1247) 쿼리 검색 중: 묘비 건립 시기 표현 어문규정
# (4/1247) 쿼리 검색 중: 저장할까요 취소할까요 맞춤법 어문규정
# (5/1247) 쿼리 검색 중: 조사 생략 가능 여부 에어컨 명사구
# (6/1247) 쿼리 검색 중: 어문규정 어문규범 부합 여부 문장 수정 이유
# (7/1247) 쿼리 검색 중: 의존명사 풀이 풀은 두음법칙
# (8/1247) 쿼리 검색 중: 관형격 조사 '의' 띄어쓰기
# (9/1247) 쿼리 검색 중: 2020 2021 기간 표기 숫자 띄어쓰기
# (10/1247) 쿼리 검색 중: 관형격 조사 '의'의 중복 사용, '청나라의'에서 '의' 생략 가능
# (11/1247) 쿼리 검색 중: 관형격 조사 '은' 띄어쓰기, 서술어 연결 어미 '-을 것이다' 맞춤법
# (12/1247) 쿼리 검색 중: 의존명사 플래그 플래그 맞춤법 국립국어원 표준국어대사전
# (13/1247) 쿼리 검색 중: 조사 '로서' '로써' 구분
# (14/1247) 쿼리 검색 중: 히치하이크 두음법칙
# (15/1247) 쿼리 검색 중: 의존명사 '해지다' 어간 활용 두음법칙
# (16/1247) 쿼리 검색 중: 의존명사 구절 귀절 한자어 표기
# (17/1247) 쿼리 검색 중: 의존명사 애드리브 외래어 표기법
# (18/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 서술어 호응, 명사 형태, 띄어쓰기
# (19/1247) 쿼리 검색 중: 의존명사 갭 개프 두음법칙
# (20/1247) 쿼리 검색 중: 연락할게 어미 '-ㄹ게' 맞춤법
# (21/1247) 쿼리 검색 중: 의존명사 튀기 트기 잡종어
# (22/1247) 쿼리 검색 중: 명사 '재털이' 표준어 '재떨이'
# (23/1247) 쿼리 검색 중: 조사 '이게' 부정 표현 어미 '-은데' 맞춤법
# (24/1247) 쿼리 검색 중: 동사 '되다' 활용, 어간과 어미 결합, 맞춤법, '되다'의 보조동사 활용
# (25/1247) 쿼리 검색 중: 일자 표기 숫자 한글 영문 띄어쓰기
# (26/1247) 쿼리 검색 중: 의존명사 검 껌 두음법칙
# (27/1247) 쿼리 검색 중: 존대 표현 윗채 위채 존댓말 표준어
# (28/1247) 쿼리 검색 중: 조사 '대로' 띄어쓰기
# (29/1247) 쿼리 검색 중: 문장부호 쉼표 용언 활용
# (30/1247) 쿼리 검색 중: 관형사형 어미 '-(으)ㄴ'과 '났다'의 결합, 구어체 표기, 표준어 규정
# (31/1247) 쿼리 검색 중: 샛별 새벽별 두음법칙
# (32/1247) 쿼리 검색 중: 의존명사 '-던' 어미 활용
# (33/1247) 쿼리 검색 중: 한자어 접미사 '쪽' 띄어쓰기, 한자어 '툇마루' 띄어쓰기, 한자어 '난간' 띄어쓰기, 한자어 '아자무니' 띄어쓰기
# (34/1247) 쿼리 검색 중: 관형사 형용사 어근 표준어 표기
# (35/1247) 쿼리 검색 중: 동사 '기대다' 활용 어미 '-시-' 존대 표현
# (36/1247) 쿼리 검색 중: 이삼십 대 문장부호 사용 간략 표기
# (37/1247) 쿼리 검색 중: 의존명사 소리 명사화 어미 '-은' 형용사화 어미 '-쩍다'
# (38/1247) 쿼리 검색 중: 동사 '나았다' 활용 어간과 어미
# (39/1247) 쿼리 검색 중: 부은 개울물 두음법칙
# (40/1247) 쿼리 검색 중: 동사 '붙이다' 활용 표준어 맞춤법
# (41/1247) 쿼리 검색 중: 관형사 '괴퍅' 한글 맞춤법 표준어 표기
# (42/1247) 쿼리 검색 중: 동사 '가지다' 활용 형태
# (43/1247) 쿼리 검색 중: 맞혀 보세요 어간 활용 두음법칙
# (44/1247) 쿼리 검색 중: 품사 명사 복수형 한글맞춤법
# (45/1247) 쿼리 검색 중: 문장부호 대화문 따옴표 쉼표
# (46/1247) 쿼리 검색 중: 의존명사 머랭 머렝 두음법칙
# (47/1247) 쿼리 검색 중: 의존명사 런닝 러닝 두음법칙
# (48/1247) 쿼리 검색 중: 의존명사 길다란 기다란 두음법칙
# (49/1247) 쿼리 검색 중: 의문문 어미 '-게' 사용 이유, 구어체 인용문 표기 규정
# (50/1247) 쿼리 검색 중: 지붕 한자어 고유어 표준어
# (51/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 어미 '-아서/-어서' 연결
# (52/1247) 쿼리 검색 중: 관형사형 어미 '-고'의 용법, 동사 어간과 어미의 결합, 관형사형 어미와 연결어미의 구분
# (53/1247) 쿼리 검색 중: 아기 아장아장 걷다 두음법칙
# (54/1247) 쿼리 검색 중: 중로동 속담 표준어 규정 고유어
# (55/1247) 쿼리 검색 중: 관형사 순서 숫자 한글 수사 한글화
# (56/1247) 쿼리 검색 중: 문장부호 쉼표 따옴표 문장부호사용법
# (57/1247) 쿼리 검색 중: 애니메이션 표기 맞춤법 두음법칙
# (58/1247) 쿼리 검색 중: 부사 하루종일 붙여쓰기
# (59/1247) 쿼리 검색 중: 자칫하면 띄어쓰기 맞춤법 두음법칙
# (60/1247) 쿼리 검색 중: 의존명사 데이터 정보 데이터의_올바른_표기
# (61/1247) 쿼리 검색 중: 의존명사 명사구 한자어 두음법칙
# (62/1247) 쿼리 검색 중: 의존명사 '소리' 명사화 어미 '-(으)ㅁ' 활용
# (63/1247) 쿼리 검색 중: 명사 '수레' 띄어쓰기, 명사 '가득' 띄어쓰기
# (64/1247) 쿼리 검색 중: 문장부호 생략된 문장 부호 추가 맞춤법 규정
# (65/1247) 쿼리 검색 중: 의존명사 꾀꼬리 꾀꼴이 두음법칙
# (66/1247) 쿼리 검색 중: 관형격 조사 '님의' 띄어쓰기, 서술격 조사 '시다' 활용
# (67/1247) 쿼리 검색 중: 문장부호 문장종결표현 마침표
# (68/1247) 쿼리 검색 중: 의존명사 명사화표현 띄어쓰기
# (69/1247) 쿼리 검색 중: 덤핑 두음법칙
# (70/1247) 쿼리 검색 중: 부정적 의미 어근 '마뜩하다' 어미 '-찮게' '-잖게' 표기
# (71/1247) 쿼리 검색 중: 문장 부사어 조사 어미 맞춤법 예요 예요
# (72/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 구어체 관용 표현, 동사 '나다' 활용, 부사 '기름'의 위치, 구어적 비표준어 표현
# (73/1247) 쿼리 검색 중: 의미 소 숫소 수소 한글맞춤법
# (74/1247) 쿼리 검색 중: 의존명사 숫 수놈 한글맞춤법
# (75/1247) 쿼리 검색 중: 의존명사 집 새집 두음법칙
# (76/1247) 쿼리 검색 중: 맞춤법 '-을걸' 어문규정
# (77/1247) 쿼리 검색 중: 유유상종 유의어 선택 맞춤법
# (78/1247) 쿼리 검색 중: 관형사 형용사 어근 두음법칙
# (79/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 호격 조사 '간'의 띄어쓰기, 예의 띄어쓰기
# (80/1247) 쿼리 검색 중: 지정격 조사 '으로써'의 올바른 사용, 지정격 조사 '으로서'와의 구분
# (81/1247) 쿼리 검색 중: 동사 '되다' 활용 어간과 어미 '-여' 결합 부사 '-여' 활용 사동 표현과 피동 표현 구분
# (82/1247) 쿼리 검색 중: 동사 '바라다' 어미 활용
# (83/1247) 쿼리 검색 중: 의존명사 전화 보조동사 연결어미 '-어' 용언 활용
# (84/1247) 쿼리 검색 중: 에너지량 에너지양 두음법칙
# (85/1247) 쿼리 검색 중: 이온량 수량 표현 단위 명사화
# (86/1247) 쿼리 검색 중: '캐찹' '케첩' 표준어 표기
# (87/1247) 쿼리 검색 중: 공약 맞춤법 표준어 띄어쓰기
# (88/1247) 쿼리 검색 중: 부사 '귀찮게' 부사화 접미사 '-이' 불필요
# (89/1247) 쿼리 검색 중: 의존명사 가스 까스 두음법칙
# (90/1247) 쿼리 검색 중: 간 단위표현 한옥 구성 전통가옥 표기
# (91/1247) 쿼리 검색 중: 어문규정 섭취 제한양 주간 음주 횟수 맞춤법 어법
# (92/1247) 쿼리 검색 중: 동사 활용 피동 표현 어미 '-었다' '-았다'
# (93/1247) 쿼리 검색 중: 동사 어간과 어미 연결 어미 '-아/어' 활용
# (94/1247) 쿼리 검색 중: 누리 소통망(SNS) 어문 규범 맞춤법 오류 수정 두음법칙 외래어 표기
# (95/1247) 쿼리 검색 중: 되요 돼요 어미 '-어요' 연결
# (96/1247) 쿼리 검색 중: 동사 '늘리다' 활용 늘였다
# (97/1247) 쿼리 검색 중: 의존명사 수 숫자 두음법칙
# (98/1247) 쿼리 검색 중: 간직할게요 어미 '-ㄹ게' 활용
# (99/1247) 쿼리 검색 중: 의존명사 피름 필름 두음법칙
# (100/1247) 쿼리 검색 중: 맞춤법 어미 활용 구어체 표준어
# (101/1247) 쿼리 검색 중: 관형사 수사 발음 규칙 숫자 읽기 두음법칙
# (102/1247) 쿼리 검색 중: 외래어 표기법 영어 relax
# (103/1247) 쿼리 검색 중: 의존명사 기럭이 기러기 두음법칙
# (104/1247) 쿼리 검색 중: 조사 선택 병원 장소 명사 뒤 조사 사용
# (105/1247) 쿼리 검색 중: 의존명사 명사 조사 두음법칙
# (106/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 어문규정
# (107/1247) 쿼리 검색 중: 의존명사 김치 담그다 표준어 규정
# (108/1247) 쿼리 검색 중: 의존명사 리넨 린넨 외래어표기법
# (109/1247) 쿼리 검색 중: 동사 '넘어지다' 활용, 명사 '멍' 표기, 관형사형 어미, 외래어 한글 표기
# (110/1247) 쿼리 검색 중: 문장 부호 쉼표 생략된 경우 사용법
# (111/1247) 쿼리 검색 중: 문장부호 쉼표 용법, 문장부호 콜론 용법, 문장부호 괄호 용법
# (112/1247) 쿼리 검색 중: 주어 생략 어문규정 문장성분 호응
# (113/1247) 쿼리 검색 중: 의존명사 수프 스프 외래어표기법
# (114/1247) 쿼리 검색 중: 의존명사 시퍼래 시퍼레 색상 형용사 어근 두음법칙
# (115/1247) 쿼리 검색 중: 조사 어미 '-도록' 연결
# (116/1247) 쿼리 검색 중: 의존명사 리턴 리탄 두음법칙
# (117/1247) 쿼리 검색 중: 주제어 나열 어문 규범 주제어 구분 표기
# (118/1247) 쿼리 검색 중: 관형사 맨 앞 두음법칙
# (119/1247) 쿼리 검색 중: 공사 한자어 띄어쓰기
# (120/1247) 쿼리 검색 중: 맞춤법 어미 '-쟎아' '-잖아' 표준어 규정
# (121/1247) 쿼리 검색 중: 의존명사 자리 두음법칙
# (122/1247) 쿼리 검색 중: 동사 명령형 어미 '-어라' 사용
# (123/1247) 쿼리 검색 중: 의존명사 칼라 컬러 외래어 표기법
# (124/1247) 쿼리 검색 중: 부사 싹둑 두음법칙
# (125/1247) 쿼리 검색 중: 동사 '귀찮아 하다' 활용, 형용사 '귀찮다' 올바른 활용
# (126/1247) 쿼리 검색 중: 하동 최 참판댁에/하동 최 참판댁에 관형격 조사 '의' 생략 가능
# (127/1247) 쿼리 검색 중: 동사 '먹다' 어간 활용 어미 '-으려고'
# (128/1247) 쿼리 검색 중: 되도 돼도 되다 어간 활용
# (129/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 대화체 존댓말 어미 적절성, 동사 '이야기하다' 활용 형태
# (130/1247) 쿼리 검색 중: 육월 유월 월인두음법칙
# (131/1247) 쿼리 검색 중: 지리적 거리 표현 '~정도는' 띄어쓰기
# (132/1247) 쿼리 검색 중: 고려사 인물 표기법 역사적 사실 서술 어순 맞춤법
# (133/1247) 쿼리 검색 중: 동사 '바라다' 어미 '-었-' 활용
# (134/1247) 쿼리 검색 중: 예 아니오 두음법칙
# (135/1247) 쿼리 검색 중: 의존명사 '상황' 띄어쓰기, 관형격 조사 '에' 띄어쓰기, 어미 '-던지' 맞춤법
# (136/1247) 쿼리 검색 중: 관형사형 어미 '-(으)ㄴ'의 올바른 사용, 서술격 조사 '이다'의 활용, 문장 부호의 올바른 사용
# (137/1247) 쿼리 검색 중: 관용 표현 인용부호 띄어쓰기
# (138/1247) 쿼리 검색 중: 의존명사 '채' 띄어쓰기, 한자어 접미사 '채' 띄어쓰기 규정
# (139/1247) 쿼리 검색 중: 동사 '싶다' 보조동사 '어지다' 어간 활용
# (140/1247) 쿼리 검색 중: 스포트라이트 스폿라이트 외래어 표기법
# (141/1247) 쿼리 검색 중: 동사 '맞다' 목적어 위치 어순 주사 주사약
# (142/1247) 쿼리 검색 중: 관형사 연노 연로 한자어 한글표현
# (143/1247) 쿼리 검색 중: 관형사 '일년도' 띄어쓰기 '일 년'
# (144/1247) 쿼리 검색 중: 맞배지붕 맞배집 용어사용 일관성
# (145/1247) 쿼리 검색 중: 외래어 표기법 플루트
# (146/1247) 쿼리 검색 중: 맞춤법 '할걸' 어간 활용
# (147/1247) 쿼리 검색 중: 외래어 표기법 페퍼민트
# (148/1247) 쿼리 검색 중: 조사 접속 조사 명사형 어미 연결 어문 규범
# (149/1247) 쿼리 검색 중: 의존명사 등등 띄어쓰기
# (150/1247) 쿼리 검색 중: 외래어 표기법 어댑터 어뎁터
# (151/1247) 쿼리 검색 중: 어간 활용 어미 '-리' 연결법 표준어 규정
# (152/1247) 쿼리 검색 중: 문장부호 쉼표 느낌표 문장종결자
# (153/1247) 쿼리 검색 중: 전라남도 신안 지역 발견 의미 문장 어문규범 맞춤법
# (154/1247) 쿼리 검색 중: 의존명사 '해'의 쓰임새 두음법칙
# (155/1247) 쿼리 검색 중: 어문규정 도서관 명사화 표현
# (156/1247) 쿼리 검색 중: 외래어 표기법 영어 f 한글 표기
# (157/1247) 쿼리 검색 중: 의존명사 파스텔 빠스텔 외래어표기법
# (158/1247) 쿼리 검색 중: 의존명사 '도' 띄어쓰기, 부정 부사 '거들떠' 붙여쓰기
# (159/1247) 쿼리 검색 중: 되요 돼요 어미 활용 돼라 되라 맞춤법
# (160/1247) 쿼리 검색 중: 제목 표기 원칙
# (161/1247) 쿼리 검색 중: 의존명사 크림 명사구표기 두음법칙
# (162/1247) 쿼리 검색 중: 외래어 표기법 케비닛 캐비닛
# (163/1247) 쿼리 검색 중: 의존명사 트레이드 외래어 한글표기
# (164/1247) 쿼리 검색 중: 의존명사 후련해 어간 어미
# (165/1247) 쿼리 검색 중: 의존명사 닭 두음법칙
# (166/1247) 쿼리 검색 중: 의존명사 디딘 동사 활용 피동 표현
# (167/1247) 쿼리 검색 중: 문장 부호 대시
# (168/1247) 쿼리 검색 중: 맞춤법 '많다'의 활용, 어미 '-어' 올바른 형태, 비교 표현
# (169/1247) 쿼리 검색 중: 의존명사 내레이션 나레이션 외래어표기법
# (170/1247) 쿼리 검색 중: 맞춤법 '거봐요' 띄어쓰기 붙여쓰기
# (171/1247) 쿼리 검색 중: 의존명사 다음 날 띄어쓰기
# (172/1247) 쿼리 검색 중: 지명 한글표기 표준어규정
# (173/1247) 쿼리 검색 중: 용언 어간 활용 한글 맞춤법 어미 '-든지'
# (174/1247) 쿼리 검색 중: 관형어 '차가운'과 '3월의' 결합, 비유적 표현, 연두빛 바람 어휘 선택
# (175/1247) 쿼리 검색 중: 의존명사 '주세요' 보조용언 붙여쓰기
# (176/1247) 쿼리 검색 중: 날짜 표기법 연도 월 일 점 표기
# (177/1247) 쿼리 검색 중: 관형어 숫자 한글 숫자 띄어쓰기
# (178/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 동사 '파악해오다' 활용 형태, 과거 시제 선어말 어미 '-아/어오다'
# (179/1247) 쿼리 검색 중: 의존명사 명 수량 띄어쓰기
# (180/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 띄어쓰기
# (181/1247) 쿼리 검색 중: 의문문 종결어미 어미 활용 표준어 규정
# (182/1247) 쿼리 검색 중: 의존명사 신 씬 두음법칙
# (183/1247) 쿼리 검색 중: 의존명사 잔 단위 명사 띄어쓰기
# (184/1247) 쿼리 검색 중: 의존명사 명사절 줄임표현 연결어미
# (185/1247) 쿼리 검색 중: 도쿄 일본 지명 로마자 표기
# (186/1247) 쿼리 검색 중: 관형격 조사 '이/가' 용법, 서술격 조사 '이다' 생략 및 관형격 조사 중첩
# (187/1247) 쿼리 검색 중: 문장부호 생략된 문장 부호 추가 맞춤법
# (188/1247) 쿼리 검색 중: 관형격 조사 '은'의 용법, 주어의 호응과 서술어의 연결, 문장 성분의 호응과 어문 규범
# (189/1247) 쿼리 검색 중: 조사 '의' 생략 가능성 띄어쓰기 붙여쓰기
# (190/1247) 쿼리 검색 중: 의존명사 해어핀 헤어핀 두음법칙
# (191/1247) 쿼리 검색 중: 계절 명사 한 철 띄어쓰기
# (192/1247) 쿼리 검색 중: 피동 표현 활용 어간 활용 불규칙 동사
# (193/1247) 쿼리 검색 중: 존댓말 어미 '-어 주세요' 올바른 사용
# (194/1247) 쿼리 검색 중: 북엔드 부크엔드 두음법칙
# (195/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 구어체 어미 '-네'의 문어체 표현
# (196/1247) 쿼리 검색 중: 연도 표기 숫자 읽기 규칙
# (197/1247) 쿼리 검색 중: '돈가스' 표준어 표기
# (198/1247) 쿼리 검색 중: 의존명사 양 량 두음법칙
# (199/1247) 쿼리 검색 중: 동사 어간 활용 피동 표현 맞춤법
# (200/1247) 쿼리 검색 중: 동사 '정하다' 어간 활용 어미 '-도록' 결합
# (201/1247) 쿼리 검색 중: 의존명사 샘 새암 두음법칙
# (202/1247) 쿼리 검색 중: 부화뢰동 어휘 사용 적절성 표준어 규정
# (203/1247) 쿼리 검색 중: 외래어 표기법 국제화 표기법 두음법칙
# (204/1247) 쿼리 검색 중: 설비음 설비음 맞춤법 표준어 규정
# (205/1247) 쿼리 검색 중: 의존명사 배기 박이 한자어 접미사
# (206/1247) 쿼리 검색 중: 관형사형 어미 '-는'의 색상 형용사 결합 누레
# (207/1247) 쿼리 검색 중: 의존명사 끌러 끄르어 동사 활용
# (208/1247) 쿼리 검색 중: 동사 어간 어미 활용 규정
# (209/1247) 쿼리 검색 중: 소련 소비에트 러시아어 외래어 표기법
# (210/1247) 쿼리 검색 중: 의존명사 지긋이 지그시 한숨 두음법칙
# (211/1247) 쿼리 검색 중: 되야 돼야 어간 어미 어미활용
# (212/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 지명 한글 표기, 감탄사와 조사 결합, 띄어쓰기: 명사와 명사 띄어쓰기
# (213/1247) 쿼리 검색 중: 조사 '에요' 어미 '-에요' 맞춤법
# (214/1247) 쿼리 검색 중: 문장 부호 쉼표 용언 활용
# (215/1247) 쿼리 검색 중: 의존명사 상태 명사형어미 어문규정
# (216/1247) 쿼리 검색 중: 동사 바라다 어간 어미 '-게' 활용
# (217/1247) 쿼리 검색 중: 소시지 맞춤법 표준어
# (218/1247) 쿼리 검색 중: 문장부호 온점 이중언어 문장 끝 마침표
# (219/1247) 쿼리 검색 중: 의존명사 손잡이 두음법칙
# (220/1247) 쿼리 검색 중: 동사 '있다'의 보조적 연결어미 '-(으)ㄹ께요' 사용
# (221/1247) 쿼리 검색 중: 어간 활용 어미 '-았/었-' 연결
# (222/1247) 쿼리 검색 중: 조사 '왠일로' 맞춤법 어문규정 고치기
# (223/1247) 쿼리 검색 중: 의존명사 '이오' '이요' 어미 '-오' '-요' 존댓말 어법
# (224/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 시간 명사 '년' 연결 표현, 관형격 조사 생략 규정, 시간 표현 어문 규범
# (225/1247) 쿼리 검색 중: 의존명사 시뮬레이션 외래어 표기법
# (226/1247) 쿼리 검색 중: 의존명사 보디 바디 한글맞춤법
# (227/1247) 쿼리 검색 중: 의존명사 스위치 외래어 표기법
# (228/1247) 쿼리 검색 중: 어문 규범 정답 선택 이유
# (229/1247) 쿼리 검색 중: 의존명사 잎 나뭇잎 표준어 규정
# (230/1247) 쿼리 검색 중: 용언 어간 활용 어미 '-으리요' 맞춤법
# (231/1247) 쿼리 검색 중: 동사 '잘난척하다' 활용 어미 '-아요' 결합
# (232/1247) 쿼리 검색 중: 문장 부사어 구조 어미 활용 맞춤법
# (233/1247) 쿼리 검색 중: 맞추어 맞춰 어간 어미 '-어' 활용
# (234/1247) 쿼리 검색 중: 관형격 조사 '으로'의 용법, 명사 '타자기'의 호칭 격 조사 사용, 한글 타자기 역사 대중화 표현
# (235/1247) 쿼리 검색 중: 부사 아래 알로 두음법칙
# (236/1247) 쿼리 검색 중: 동사 '넣다'의 활용, 보조동사 '가'의 사용, 명사 '바람'과 '바람 넣기
# (237/1247) 쿼리 검색 중: 관형격 조사 '–으'의 사용, '편찮다'의 표준어, 어간과 어미 결합
# (238/1247) 쿼리 검색 중: 어문규정 흡연양 흡연량 두음법칙
# (239/1247) 쿼리 검색 중: 피동 표현 사동 표현 맞춤법
# (240/1247) 쿼리 검색 중: 동사 '절차' 명사 '불가능' 어문규정 맞춤법
# (241/1247) 쿼리 검색 중: 의존명사 치다 처지다 두음법칙
# (242/1247) 쿼리 검색 중: 의존명사 '같은'의 용법 어린이같은 옷 맞춤법
# (243/1247) 쿼리 검색 중: 의존명사 해소 한글맞춤법
# (244/1247) 쿼리 검색 중: 맞춤법 '있을 수 있다' '있을 수도 있다' 띄어쓰기
# (245/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 존댓말 어미 적절성, 존재하지 않는 단어 '아는바'의 올바른 표현
# (246/1247) 쿼리 검색 중: 부사격 조사 '에'와 '에게' 사용, 동사 '내리쬐다'의 올바른 활용
# (247/1247) 쿼리 검색 중: 의존명사 일 며칠 맞춤법
# (248/1247) 쿼리 검색 중: 문장 부호 띄어쓰기 표준어 규정
# (249/1247) 쿼리 검색 중: 동사 '짓물다'의 활용, 피동 표현, 어간 어미
# (250/1247) 쿼리 검색 중: 외래어 표기법 두음법칙
# (251/1247) 쿼리 검색 중: 의존명사 야단법썩 띄어쓰기
# (252/1247) 쿼리 검색 중: 문장 부사어 날짜 표기 어문규정
# (253/1247) 쿼리 검색 중: 맞춤법 어미 연결어미 '-에요' 붙여쓰기
# (254/1247) 쿼리 검색 중: 관형사 '스물두째' 띄어쓰기, 관형사와 수사 띄어쓰기 규정
# (255/1247) 쿼리 검색 중: 맞춤법 '늘리다' '늘였다' 활용
# (256/1247) 쿼리 검색 중: 의존명사 하기 두음법칙
# (257/1247) 쿼리 검색 중: 의존명사 향기 부사 두음법칙
# (258/1247) 쿼리 검색 중: 관형사 상상지 띄어쓰기 상상하지 못했다
# (259/1247) 쿼리 검색 중: 의존명사 속 두음법칙
# (260/1247) 쿼리 검색 중: 의존명사 액세서리 외래어표기법
# (261/1247) 쿼리 검색 중: 외래어 표기법 러시아워
# (262/1247) 쿼리 검색 중: 의존명사 느닷없이 두음법칙
# (263/1247) 쿼리 검색 중: 의존명사 양 량 두음법칙
# (264/1247) 쿼리 검색 중: 적절한 인삿말 인사말 맞춤법
# (265/1247) 쿼리 검색 중: 의존명사 군데 띄어쓰기
# (266/1247) 쿼리 검색 중: 의존명사 '안' 띄어쓰기
# (267/1247) 쿼리 검색 중: 용언 활용 불규칙 활용 두음법칙
# (268/1247) 쿼리 검색 중: 의존명사 빛깔 빛갈 한글맞춤법
# (269/1247) 쿼리 검색 중: 조사 어미 어간 활용 아닌 아닌예요 아닌아요 아닌가요 아닌데요 부정표현 어미변화
# (270/1247) 쿼리 검색 중: 맞춤법 때려넣다 붙여쓰기
# (271/1247) 쿼리 검색 중: 명령문 종결어미 '-라' 사용법, 명령문 어미 '-요' 사용법, 종결어미 중첩 사용
# (272/1247) 쿼리 검색 중: 동사 '출마하다' 활용 어간 어미
# (273/1247) 쿼리 검색 중: '오전 10시 20분' 문장부호 표기
# (274/1247) 쿼리 검색 중: 의존명사 낭낭 낭랑 한자어 두음법칙
# (275/1247) 쿼리 검색 중: 의존명사 사뭇 두음법칙
# (276/1247) 쿼리 검색 중: 외래어 표기법 두음법칙
# (277/1247) 쿼리 검색 중: 동사 활용 피동 표현 어간 '-히-' '-게' '-어' 결합
# (278/1247) 쿼리 검색 중: 조사 '지만' '만' '듯싶지만서도' 어미 활용 중첩 부자연스러움
# (279/1247) 쿼리 검색 중: 의존명사 프린터 푸린터 두음법칙
# (280/1247) 쿼리 검색 중: 2026 월드컵 표기 규정 외래어 한글 표기
# (281/1247) 쿼리 검색 중: 의존명사 툇간 퇴간 한글맞춤법
# (282/1247) 쿼리 검색 중: 부사 '만하다'의 올바른 사용
# (283/1247) 쿼리 검색 중: 의존명사 계절 명사열 나열 띄어쓰기
# (284/1247) 쿼리 검색 중: 의존명사 안 두음법칙
# (285/1247) 쿼리 검색 중: 로봇 로보트 한글 맞춤법 표준어 규정
# (286/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 업무 관할 지역 구분 표현, 숫자 한글 표기 규정
# (287/1247) 쿼리 검색 중: 의존명사 다리 형용사 어근 두음법칙
# (288/1247) 쿼리 검색 중: 의존명사 타월 타올 외래어 한글표기
# (289/1247) 쿼리 검색 중: 조사 '―'의 사용, 어미 '-아요/-어' 결합, 구어체 존댓말 규정
# (290/1247) 쿼리 검색 중: 문장 부호 호칭어 숫자 붙여쓰기 띄어쓰기
# (291/1247) 쿼리 검색 중: 고유명사 결합형 띄어쓰기 표준어사전
# (292/1247) 쿼리 검색 중: 포함 시키다 포함하다 맞춤법 표준어
# (293/1247) 쿼리 검색 중: 의존명사 어미 두음법칙
# (294/1247) 쿼리 검색 중: 조사 '이밖에도' 띄어쓰기, 부사와 조사 띄어쓰기 규정
# (295/1247) 쿼리 검색 중: 의존명사 안치다 앉히다 동사어간 활용
# (296/1247) 쿼리 검색 중: 의존명사 '처다' '처다보다' 맞춤법
# (297/1247) 쿼리 검색 중: 의존명사 화원 동사 활용 가꾸다
# (298/1247) 쿼리 검색 중: 의존명사 퍼스널 두음법칙
# (299/1247) 쿼리 검색 중: 의존명사 귓머리 귀밑머리 표준어 규정
# (300/1247) 쿼리 검색 중: 의존명사 숫- 수염소 두음법칙
# (301/1247) 쿼리 검색 중: 문장부호 쉼표 용언 활용
# (302/1247) 쿼리 검색 중: 의존명사 지점 명사화 두음법칙
# (303/1247) 쿼리 검색 중: 의존명사 '얘기' 보조동사 '하-' 어미 '-던가요'
# (304/1247) 쿼리 검색 중: 동사 '읽어들이다' 맞춤법 표준어
# (305/1247) 쿼리 검색 중: 관형사 최근 숫자 한글 맞춤법 연평균 증감율 띄어쓰기
# (306/1247) 쿼리 검색 중: 존경의 표현 삼가다 명사형 어미
# (307/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 서술격 조사 '이다' 생략 가능성, 외래어 표기 '화가' 띄어쓰기, 소유 표현 '에게'의 문법성, 고유명사 '김남길' 띄어쓰기, 서술어 '그리게 하다' 문법성, 보조동사 '하다'의 활용, 화첩 명사 사용법, 문장 종결 표현 '이예요'의 맞춤법
# (308/1247) 쿼리 검색 중: 의존명사 버그 두음법칙
# (309/1247) 쿼리 검색 중: 닭우리 닭장 표준어 규정
# (310/1247) 쿼리 검색 중: 괄호 열고 공포는 제외 써야 하는 거 아니야?
# 문장 부호 띄어쓰기 문장 안에서 '괄호' 사용
# (311/1247) 쿼리 검색 중: 의존명사 덩어리 넙죽 두음법칙
# (312/1247) 쿼리 검색 중: 의존명사 알코올 알콜 표준어 규정
# (313/1247) 쿼리 검색 중: 의존명사 '좋으리라' 연결어미 '-으리라' 맞춤법
# (314/1247) 쿼리 검색 중: 의존명사 스테이크 외래어 표기법
# (315/1247) 쿼리 검색 중: 동사 '편안하다' 피동 표현 어미
# (316/1247) 쿼리 검색 중: 의존명사 집어넣다 어간 활용 표준어 맞춤법
# (317/1247) 쿼리 검색 중: 뚝배기 표준어 맞춤법 두음법칙
# (318/1247) 쿼리 검색 중: 관형사형 어미 '-대로' 띄어쓰기, 동사 '말하다' 활용
# (319/1247) 쿼리 검색 중: 의존명사 수막새 명사형어미
# (320/1247) 쿼리 검색 중: 샐러드 표준어 맞춤법
# (321/1247) 쿼리 검색 중: 의존명사 농기구 예요 맞춤법
# (322/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 명령문에서 '장'의 호칭 사용, 동사 '받다'의 활용, 공문서 어문 규정
# (323/1247) 쿼리 검색 중: 맞춤법 붕어빵 파치 표준어 사용
# (324/1247) 쿼리 검색 중: 부사 깨끗이 깨끗히 맞춤법 두음법칙
# (325/1247) 쿼리 검색 중: 문장부호 사용 규정
# (326/1247) 쿼리 검색 중: 의존명사 타깃 타겟 한글맞춤법
# (327/1247) 쿼리 검색 중: 조사 생략 어미 활용 의식치 않는다 의식하지 않는다
# (328/1247) 쿼리 검색 중: 관형사 온 가족/온가족 어근 결합 표준어
# (329/1247) 쿼리 검색 중: 의존명사 '품종' 띄어쓰기, 합성어 여부, 관형어와 의존명사 띄어쓰기 규정
# (330/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 동사 어미 활용 '-라고 했는데도' 구문, 목적어와 부사어의 어순, 일상 구어체 높임 표현, 동작의 연속 표현
# (331/1247) 쿼리 검색 중: 스쿼트 스쾃 한글 외래어표기법
# (332/1247) 쿼리 검색 중: 의존명사 율 률 한글맞춤법 제4장 제30항
# (333/1247) 쿼리 검색 중: 문장부호 사용법, 서술격 조사 '이다' 생략과 문장 부호, 구두점 생략된 문장 부호 추가
# (334/1247) 쿼리 검색 중: 용언 활용 애통하다 애통해하다
# (335/1247) 쿼리 검색 중: 조사 생략 어문규정 문장부호 사용
# (336/1247) 쿼리 검색 중: 의존명사 미터 센티미터 외래어표기법
# (337/1247) 쿼리 검색 중: 관형사형 어미 '-자' 뒤 명사 생략, '수탉'의 표준어, 두음법칙
# (338/1247) 쿼리 검색 중: 의존명사 가지 가지 두음법칙
# (339/1247) 쿼리 검색 중: 의존명사 양 량 두음법칙
# (340/1247) 쿼리 검색 중: 의존명사 숫송아지 수사 숫자 띄어쓰기
# (341/1247) 쿼리 검색 중: 들머기지 마셨으면 좋겠어요 어간 어미 어문규정
# (342/1247) 쿼리 검색 중: 의존명사 컨트롤 어문규정
# (343/1247) 쿼리 검색 중: 의존명사 빛 색상표현 한글맞춤법
# (344/1247) 쿼리 검색 중: 외래어 표기법 스페인어 딸꾹질 이포 히포
# (345/1247) 쿼리 검색 중: 부사 넘어 너머 어문규정
# (346/1247) 쿼리 검색 중: 문장부호 인용부호 따옴표 이유
# (347/1247) 쿼리 검색 중: 문장부호 쉼표(,) 용법 문장부호 사용 규정
# (348/1247) 쿼리 검색 중: 관형사 형용사 연결 어근 사이 조사 띄어쓰기
# (349/1247) 쿼리 검색 중: 의존명사 글귀 글구 두음법칙
# (350/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 띄어쓰기 보조용언 붙여쓰기
# (351/1247) 쿼리 검색 중: 의존명사 영양제 명사형어미
# (352/1247) 쿼리 검색 중: 부사 파생 접미사 삭 싹
# (353/1247) 쿼리 검색 중: 경쟁률 수사법 비교 관형사형 어미
# (354/1247) 쿼리 검색 중: 동사 '저어' 활용 어간과 어미 결합
# (355/1247) 쿼리 검색 중: 의존명사 원 단위 띄어쓰기
# (356/1247) 쿼리 검색 중: 동사 '해내다' 활용, 보조동사 '수'의 문법적 쓰임
# (357/1247) 쿼리 검색 중: 아라비아 숫자 연월일 문장부호 표기 규정
# (358/1247) 쿼리 검색 중: 의존명사 커버 카바 외래어 한글표기
# (359/1247) 쿼리 검색 중: 국어 표준어 규정 고유명사 한글 맞춤법
# (360/1247) 쿼리 검색 중: 의존명사 쇼핑 샤핑 외래어표기법
# (361/1247) 쿼리 검색 중: 보관 장식 문양 어문규범 올바른표현
# (362/1247) 쿼리 검색 중: 의존명사 클랙슨 외래어 표기법
# (363/1247) 쿼리 검색 중: 문장부호 한자어 인용부호
# (364/1247) 쿼리 검색 중: 의존명사 런치 론치 외래어 표기법
# (365/1247) 쿼리 검색 중: 동사 '하다' 어간 '하-' 뒤 '-겠-' 결합 어미 '-읍니다' '-습니다' 표준어 규정
# (366/1247) 쿼리 검색 중: 문장 부호 띄어쓰기 문장 연결
# (367/1247) 쿼리 검색 중: 의문문 종결어미 대화문 문장부호
# (368/1247) 쿼리 검색 중: 조사 결합 위치 띄어쓰기
# (369/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 동사 '기울이다'의 활용, 동사 '힘을 기울이다'의 문법성
# (370/1247) 쿼리 검색 중: 띄어쓰기 고유명사 연결형
# (371/1247) 쿼리 검색 중: 의존명사 살 됨됨 동사 '되다' 활용
# (372/1247) 쿼리 검색 중: 의존명사 값 채소 두음법칙
# (373/1247) 쿼리 검색 중: 동사 '적용하다' 활용, 명사 '률' 한글 맞춤법
# (374/1247) 쿼리 검색 중: 의존명사 '일기' 띄어쓰기
# (375/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 부정적 일반화 표현, 비속어 및 경멸적 표현 사용, 표현의 사실성과 어문 규범
# (376/1247) 쿼리 검색 중: 보던가 두음법칙
# (377/1247) 쿼리 검색 중: 단일어 복합어 국어사전 표제어
# (378/1247) 쿼리 검색 중: 어문규정 부적합 부분 수정 이유
# (379/1247) 쿼리 검색 중: 문장부호 호칭어 경칭
# (380/1247) 쿼리 검색 중: 의존명사 시간 명사구 결합 두음법칙
# (381/1247) 쿼리 검색 중: 외래어 표기법 두음법칙 외국어 발음
# (382/1247) 쿼리 검색 중: 의존명사 편 명사구 합성어
# (383/1247) 쿼리 검색 중: 외래어 표기법 한글 표기 원칙
# (384/1247) 쿼리 검색 중: 의존명사 괴여 괴다 어간 활용
# (385/1247) 쿼리 검색 중: 의존명사 놀음 놀이 두음법칙
# (386/1247) 쿼리 검색 중: 의존명사 캠핑 켐핑 두음법칙
# (387/1247) 쿼리 검색 중: 의존명사 씰 실 두음법칙
# (388/1247) 쿼리 검색 중: 의문문 종결어미 어미활용 왜요
# (389/1247) 쿼리 검색 중: 문장부호 쉼표 생략 이유 문장 종결표현
# (390/1247) 쿼리 검색 중: 단위 명사 표기 숫자와 띄어쓰기
# (391/1247) 쿼리 검색 중: 의존명사 명사구 한글맞춤법 합성어
# (392/1247) 쿼리 검색 중: 문장부호 문장표현 간략화
# (393/1247) 쿼리 검색 중: 문장부호 쉼표 접속문 종결문
# (394/1247) 쿼리 검색 중: 의존명사 멋적 멋쩍 두음법칙
# (395/1247) 쿼리 검색 중: 의존명사 칫솔 잇솔 한글맞춤법
# (396/1247) 쿼리 검색 중: 명사 파생 접미사 '-방법' '-차'의 결합 및 의미 중복
# (397/1247) 쿼리 검색 중: 의존명사 하다 어미 연결 어간 활용
# (398/1247) 쿼리 검색 중: 의존명사 칸 띄어쓰기
# (399/1247) 쿼리 검색 중: 의존명사 어귀 미류나무 표준어 규정
# (400/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 부사어 구성, 종결어미 '-았-/-었-' 활용, 비표준적 표현 여부
# (401/1247) 쿼리 검색 중: 의존명사 명사구 조사 결합 어미 활용
# (402/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 보조동사 '있다' 생략 가능성, 동사 어미 '-중이다' 활용
# (403/1247) 쿼리 검색 중: 동사 '승락' 한글 맞춤법 표준어 규정
# (404/1247) 쿼리 검색 중: 어미 '-는데' 용법
# (405/1247) 쿼리 검색 중: 의존명사 애닯 애달프 두음법칙
# (406/1247) 쿼리 검색 중: 동사 '나다' 활용 어간과 어미 결합
# (407/1247) 쿼리 검색 중: 의존명사 '메'의 활용, '산'의 관형사형, 두음법칙
# (408/1247) 쿼리 검색 중: 관형격 조사 '들'의 띄어쓰기, 동사 '꺼내다'의 활용
# (409/1247) 쿼리 검색 중: 의존명사 앎 알음 아름 의미 차이
# (410/1247) 쿼리 검색 중: 조사 어미 활용 존댓말 어미 생략
# (411/1247) 쿼리 검색 중: 의존명사 밤 야 두음법칙
# (412/1247) 쿼리 검색 중: 핼러윈 표준어 표기
# (413/1247) 쿼리 검색 중: 동사 '밤새다' 활용, 어간 '밤새우-'에 '-지 마라' 연결, 어미 올바른 형태
# (414/1247) 쿼리 검색 중: 의존명사 하다 어간 연결어미 '-겠-' 활용
# (415/1247) 쿼리 검색 중: 의존명사 계제 게제 한자어 표기
# (416/1247) 쿼리 검색 중: 의존명사 창문 관련 한글 맞춤법 뒤창
# (417/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 명사 '더미'와 '쓰러지다'의 문법적 결합, 피동 표현 '휘청거리다'의 활용
# (418/1247) 쿼리 검색 중: 문장부호 사용법, 서술격 조사 '이다' 생략과 문장부호, 구두점 적절 사용
# (419/1247) 쿼리 검색 중: 부사 '안절부절'의 띄어쓰기
# (420/1247) 쿼리 검색 중: 맞춤법 어간 어미 활용
# (421/1247) 쿼리 검색 중: 의존명사 으레 으례 두음법칙
# (422/1247) 쿼리 검색 중: 프로 정도 될까요
# (423/1247) 쿼리 검색 중: 조사 생략 어순 표준어 규정 동사 활용
# (424/1247) 쿼리 검색 중: 관형사 '그다음' 띄어쓰기, 수사와 명사 띄어쓰기
# (425/1247) 쿼리 검색 중: 의존명사 구비 굽이 한자어 한글 맞춤법
# (426/1247) 쿼리 검색 중: 의존명사 리포트 보고서 표기
# (427/1247) 쿼리 검색 중: 맞춤법 '쓸 수' 띄어쓰기
# (428/1247) 쿼리 검색 중: 의존명사 제스처 제스쳐 외래어표기법
# (429/1247) 쿼리 검색 중: 소유격 조사 '의' 올바른 사용, 소유격 조사 '의' 생략 및 잘못된 사용
# (430/1247) 쿼리 검색 중: 동사 '다 갚다' 활용, 어간과 어미 결합, 보조동사 '까지' 사용
# (431/1247) 쿼리 검색 중: 의존명사 급격이 급격히 부사 파생 접미사
# (432/1247) 쿼리 검색 중: 신조어 표준어 인정 기준
# (433/1247) 쿼리 검색 중: 관형격 조사로서 역할 용례
# (434/1247) 쿼리 검색 중: 의존명사 명사구 띄어쓰기 붙여쓰기
# (435/1247) 쿼리 검색 중: '은/는' 보조사 생략 가능성, 병렬 나열 문장, 관형절 구조
# (436/1247) 쿼리 검색 중: 부정표현 안쓰는 띄어쓰기
# (437/1247) 쿼리 검색 중: 의존명사 기 키 두음법칙
# (438/1247) 쿼리 검색 중: 동사 '되다' 활용 어간 어미 '-어' 결합
# (439/1247) 쿼리 검색 중: 지시어 '으로써' 용법 표준어 규정
# (440/1247) 쿼리 검색 중: 포르투갈어 외래어 표기법 두음법칙
# (441/1247) 쿼리 검색 중: 의존명사 모아 모으다 어근 형태
# (442/1247) 쿼리 검색 중: 문장부호 쉼표 이음표 용언 연결 어미 생략
# (443/1247) 쿼리 검색 중: 의존명사 일 걸 껄 맞춤법 휴일
# (444/1247) 쿼리 검색 중: 동사 활용 어간과 어미 결합 규정
# (445/1247) 쿼리 검색 중: 의존명사 열 렬 두음법칙
# (446/1247) 쿼리 검색 중: 전치사 명사구 띄어쓰기
# (447/1247) 쿼리 검색 중: 동사 '되다' 어간 활용 어미 '-었다'
# (448/1247) 쿼리 검색 중: 동사 '따르다' 활용 어간 '-따르-' 뒤 '-아/어' 연결
# (449/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 띄어쓰기
# (450/1247) 쿼리 검색 중: 의존명사 젠더 젠다 외래어표기법
# (451/1247) 쿼리 검색 중: 의문문 종결어미 평서문 어미로의 잘못된 사용
# (452/1247) 쿼리 검색 중: 의존명사 치즈 시즈 외래어 한글표기
# (453/1247) 쿼리 검색 중: 의존명사 만큼 접속조사
# (454/1247) 쿼리 검색 중: 피노키오 올바른 표기법
# (455/1247) 쿼리 검색 중: 의존명사 나무라 나무래 두음법칙
# (456/1247) 쿼리 검색 중: 조사 어미 연결 만들므로 만드므로 맞춤법 어간 어미활용
# (457/1247) 쿼리 검색 중: 문장부호 쉼표 생략 금지, 문장부호 콜론 또는 대시 사용
# (458/1247) 쿼리 검색 중: 어휘 선택 한글 맞춤법 탱크 올바른 표기
# (459/1247) 쿼리 검색 중: 명사 호텔 호테르 표준어 표기
# (460/1247) 쿼리 검색 중: 의존명사 귀먹어리 두음법칙
# (461/1247) 쿼리 검색 중: 동사 어간 활용 피동 표현 맞춤법
# (462/1247) 쿼리 검색 중: 맞춤법 장난 식으로 한번 해 봤다 관용적 표현 금지
# (463/1247) 쿼리 검색 중: 동사 '되다' 활용 어간 어미 '-고' 결합
# (464/1247) 쿼리 검색 중: 동사 '오다'의 의미와 어문 규범
# (465/1247) 쿼리 검색 중: 문장 부호 인용부호 따옴표 이유
# (466/1247) 쿼리 검색 중: 따옴표 중복 사용 문장부호 어문규정
# (467/1247) 쿼리 검색 중: 시든 오이 관형사형 어미 '-는' 용언 활용
# (468/1247) 쿼리 검색 중: 의존명사 예요 어미 두음법칙
# (469/1247) 쿼리 검색 중: 의존명사 계양식 게양식 한글맞춤법
# (470/1247) 쿼리 검색 중: 의존명사 바람 바램 표준어규정
# (471/1247) 쿼리 검색 중: 어미 '-던지' '-든지' 용법
# (472/1247) 쿼리 검색 중: 의존명사 조개 두음법칙
# (473/1247) 쿼리 검색 중: 의존명사 상 복수표현 어미활용
# (474/1247) 쿼리 검색 중: 의존명사 숟가락 숫가락 한글맞춤법
# (475/1247) 쿼리 검색 중: 날짜 표기 숫자 띄어쓰기
# (476/1247) 쿼리 검색 중: 프랑스 외래어 표기법 두음법칙
# (477/1247) 쿼리 검색 중: 의존명사 담다 담그다 동사어간 활용
# (478/1247) 쿼리 검색 중: 날짜 : 2024년 3월 1일 어문규범 날짜 표기
# (479/1247) 쿼리 검색 중: 의존명사 브러시 브러시
# (480/1247) 쿼리 검색 중: 의존명사 율 률 한글맞춤법 제4장 제40항
# (481/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 연도 표기 숫자 한글 표기법, 연도 표기 '년' 띄어쓰기
# (482/1247) 쿼리 검색 중: 용언 어간 활용 두음법칙
# (483/1247) 쿼리 검색 중: 어미 '-구나' 활용, 종결 어미 '-구나' 올바른 사용
# (484/1247) 쿼리 검색 중: 의존명사 채일 챌 두음법칙
# (485/1247) 쿼리 검색 중: 시제 어미 '-기' 활용 표준어 규정
# (486/1247) 쿼리 검색 중: 의존명사 밭 바치다 한자어 고유어
# (487/1247) 쿼리 검색 중: 관형사형 어미 '-은/-ㄴ'과 명사 결합, 띄어쓰기, '계재'의 맞춤법
# (488/1247) 쿼리 검색 중: 의존명사 온도 조사 에요 예요
# (489/1247) 쿼리 검색 중: 의존명사 커튼 커텐 표준어표기
# (490/1247) 쿼리 검색 중: 외래어 표기법 두음법칙
# (491/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 구어체 허용, 동사 시제 활용, 전어 표기
# (492/1247) 쿼리 검색 중: 호칭 접미사 '-장인', '사촌 형제' 촌수 표현, 존댓말 어미
# (493/1247) 쿼리 검색 중: 국립국어원 표준국어대사전 겸직 의미 겸하다
# (494/1247) 쿼리 검색 중: 용언 어간 어미 되 돼 어간어미구분
# (495/1247) 쿼리 검색 중: 의존명사 이어폰 얽힘 얽히다
# (496/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 주어와 서술어의 호응, 공공기관 명칭 표기
# (497/1247) 쿼리 검색 중: 관형사 '이'의 지시 대상, 지시대명사, 대명사 사용, '이'와 '그'의 구분, 문맥에 따른 대명사 선택
# (498/1247) 쿼리 검색 중: 의존명사 거 예요 띄어쓰기
# (499/1247) 쿼리 검색 중: 의존명사 미장이
# (500/1247) 쿼리 검색 중: 의존명사 일 보조동사 못하다 띄어쓰기
# (501/1247) 쿼리 검색 중: 의존명사 '다음' 문장 부정 표현 어문규정
# (502/1247) 쿼리 검색 중: 의존명사 막 막대 두음법칙
# (503/1247) 쿼리 검색 중: 웬일로 고기값이 떨어졌다 어문규범 두음법칙 맞춤법 관형사형 어미
# (504/1247) 쿼리 검색 중: 의문문 종결 표현 어미 '-지?' '-지?' 존댓말 존비관계
# (505/1247) 쿼리 검색 중: 동사 '폐를 끼치다' 활용, 피동 표현, 어미 '-군요' 결합
# (506/1247) 쿼리 검색 중: 의존명사 센스 넌센스 외래어표기법
# (507/1247) 쿼리 검색 중: 의존명사 척척 관형사형 어미 띄어쓰기
# (508/1247) 쿼리 검색 중: 의존명사 심상지 심상치 두음법칙
# (509/1247) 쿼리 검색 중: 의존명사 칸 한자어 수사 맞춤법
# (510/1247) 쿼리 검색 중: 외래어 표기법 가족 패밀리
# (511/1247) 쿼리 검색 중: 의존명사 '-며' 연결어미 '-어' 구어체 줄임표'' 누군지 맞히다
# (512/1247) 쿼리 검색 중: 의존명사 물 길르 길러 두음법칙
# (513/1247) 쿼리 검색 중: 관형격 조사 '데'의 용법, 부사 '미끄럽다'의 관형사형, 서술어 생략과 문장 구조, 부사와 관형사의 구분, 문장 성분 분석
# (514/1247) 쿼리 검색 중: 필수 항목 나열 어문규정
# (515/1247) 쿼리 검색 중: 의존명사 '-의' 생략 가능성, 관형격 조사 '-의' 생략 규정, 관형격 조사 생략 예외
# (516/1247) 쿼리 검색 중: 의존명사 조사 어미 띄어쓰기
# (517/1247) 쿼리 검색 중: 의존명사 식목일 부치다 붙이다
# (518/1247) 쿼리 검색 중: 동사 '내리쬐다' 피동 표현 맞춤법
# (519/1247) 쿼리 검색 중: 행렬 고유값 두음법칙
# (520/1247) 쿼리 검색 중: 의존명사 북엔드 외래어 표기법
# (521/1247) 쿼리 검색 중: 수사와 관형사 형태 가치 가치의 띄어쓰기
# (522/1247) 쿼리 검색 중: 의존명사 패션 패숀 두음법칙
# (523/1247) 쿼리 검색 중: 의존명사 엘리베이터 외래어표기법
# (524/1247) 쿼리 검색 중: 명사+명사 결합 띄어쓰기
# (525/1247) 쿼리 검색 중: 문장부호 쉼표 생략 이유 문장 종결자
# (526/1247) 쿼리 검색 중: 우리말; 슈룹, 헤윰 맞춤법 표준어 규정
# (527/1247) 쿼리 검색 중: 의존명사 입 두음법칙
# (528/1247) 쿼리 검색 중: 의존명사 늘리다 늘여 활용
# (529/1247) 쿼리 검색 중: 의존명사 칼럼 컬럼 외래어표기법
# (530/1247) 쿼리 검색 중: 문장부호 인용부호 따옴표 이유 설명
# (531/1247) 쿼리 검색 중: 수치 표현 감가상각율 한글 맞춤법 숫자 표기
# (532/1247) 쿼리 검색 중: 약속건대 약속의 연결어미 '-건대'
# (533/1247) 쿼리 검색 중: 프랜차이즈 외래어 표기법
# (534/1247) 쿼리 검색 중: 문장부호 의문문 마침표
# (535/1247) 쿼리 검색 중: 조사 결합 어미 활용
# (536/1247) 쿼리 검색 중: 의문문 어미 활용 평서문 어미 중복
# (537/1247) 쿼리 검색 중: 문장 부호 쉼표 생략된 경우 문장 종결표현
# (538/1247) 쿼리 검색 중: 의존명사 란 난 한자어 표기 차이
# (539/1247) 쿼리 검색 중: 조사 결합형 밖에 두음법칙
# (540/1247) 쿼리 검색 중: 문장부호 쉼표 생략 금지, 문장부호 괄호 사용 이유, 문장부호 문장 연결
# (541/1247) 쿼리 검색 중: 의존명사 돼지 퇘사 표준어 규정
# (542/1247) 쿼리 검색 중: 동사 '하다' 활용 어간 말음 법칙
# (543/1247) 쿼리 검색 중: 의존명사 빛 한자어 합성어 두음법칙
# (544/1247) 쿼리 검색 중: 관형사 지난 형용사 겨울 어간 활용 어미 '-았-/-었-'
# (545/1247) 쿼리 검색 중: 의존명사 파일 화일 한글맞춤법
# (546/1247) 쿼리 검색 중: '굳이' 맞춤법 두음법칙
# (547/1247) 쿼리 검색 중: 동사 '취조하다' 활용, 어간과 어미 결합, 비표준적 표현
# (548/1247) 쿼리 검색 중: 의존명사 '서' 띄어쓰기 어문규정
# (549/1247) 쿼리 검색 중: 의존명사 바닥에서 조사 결합 부사 어떻게 피겠는가 피다 활용
# (550/1247) 쿼리 검색 중: 동사 '할 수 있다' 어미 활용
# (551/1247) 쿼리 검색 중: 문장부호 인용문 따옴표 쉼표
# (552/1247) 쿼리 검색 중: 의존명사 색 쌕색 띄어쓰기
# (553/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 가장격 의미 및 표현 규정
# (554/1247) 쿼리 검색 중: 의존명사 쌍둥이 쌍둥이 두음법칙
# (555/1247) 쿼리 검색 중: 문장 부사어 조사 어미 어문규정 맞춤법
# (556/1247) 쿼리 검색 중: 동사 '띄다'의 의미 구분 띄어쓰기
# (557/1247) 쿼리 검색 중: 의존명사 명 수사 띄어쓰기
# (558/1247) 쿼리 검색 중: 문장 부호 쉼표 생략 가능
# (559/1247) 쿼리 검색 중: 프리제르 프리졔르 두음법칙
# (560/1247) 쿼리 검색 중: 문장부호 쉼표 용언 연결 문장구조
# (561/1247) 쿼리 검색 중: 조사 '텐데' 맞춤법
# (562/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 고려 말 조선 초 띄어쓰기, 매병 한자어 고유어 띄어쓰기
# (563/1247) 쿼리 검색 중: 문장부호 인용부호 따옴표 사용법
# (564/1247) 쿼리 검색 중: 맞춤법 잔전 잔돈 띄어쓰기
# (565/1247) 쿼리 검색 중: 의존명사 재킷 자켓 외래어표기법
# (566/1247) 쿼리 검색 중: 관형사 싹삭- 관형사 어근 싹- 부사 싹싹- 어문규정 맞춤법
# (567/1247) 쿼리 검색 중: 부사 '주의' 연결어미 '-세요'
# (568/1247) 쿼리 검색 중: 어미 '-는 게' 활용, 구어체 어미 '-껄' 표준어 표기
# (569/1247) 쿼리 검색 중: 동사 '하다' 활용, 명령형 어미, 인용절 접속
# (570/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 존댓말 어미, 속담 표기
# (571/1247) 쿼리 검색 중: 맞춤법 '불' 띄어쓰기, 관형어와 의존명사 띄어쓰기
# (572/1247) 쿼리 검색 중: 의존명사 '쟎고' 맞춤법 '잖고'
# (573/1247) 쿼리 검색 중: 의존명사 연결어미 띄어쓰기
# (574/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 외래어 표기법, 지명 표기법
# (575/1247) 쿼리 검색 중: 조사 '대로' 띄어쓰기
# (576/1247) 쿼리 검색 중: 맞춤법 존댓말 어미
# (577/1247) 쿼리 검색 중: 의존명사 틈틈이 틈틈히 한글맞춤법
# (578/1247) 쿼리 검색 중: 의존명사 장단지 장딴지 두음법칙
# (579/1247) 쿼리 검색 중: 동사 '다하다' 보조동사 '하다' 중복
# (580/1247) 쿼리 검색 중: 의존명사 문제 없이 부사격 조사 없이
# (581/1247) 쿼리 검색 중: 법하지만서도 연결어미 어문규정 맞춤법
# (582/1247) 쿼리 검색 중: 관형사 '멀티' 한글 맞춤법 외래어 표기
# (583/1247) 쿼리 검색 중: 부사 꼼꼼이 꼼꼼히 한글맞춤법
# (584/1247) 쿼리 검색 중: 시각 표현 분 단위 표기법, 시간 단위 띄어쓰기, 정시와 분 단위 띄어쓰기
# (585/1247) 쿼리 검색 중: 문장부호 대시 쉼표 안
# (586/1247) 쿼리 검색 중: 문장부호 인용부호 따옴표 사용 이유
# (587/1247) 쿼리 검색 중: 의존명사 마음 형용사 활용 굳히다 구개음화
# (588/1247) 쿼리 검색 중: 동사 '가지다' 활용 '-어놓다' 어간 결합
# (589/1247) 쿼리 검색 중: 문장부호 혼용 금지 쉼표 용법 결합 범죄 유형
# (590/1247) 쿼리 검색 중: 동사 '동의하다' 활용 어간 어미 '-던' 연결
# (591/1247) 쿼리 검색 중: 년식 년도 맞춤법 표준어 규정
# (592/1247) 쿼리 검색 중: 의존명사 스팟 spot 두음법칙
# (593/1247) 쿼리 검색 중: 의존명사 호두 가래 두음법칙
# (594/1247) 쿼리 검색 중: 3시 15분~4시 15분 문장부호 표기법
# (595/1247) 쿼리 검색 중: 조사 결합 어근 합성어 띄어쓰기
# (596/1247) 쿼리 검색 중: 문장 부호 따옴표 이유 문장 부호 규정
# (597/1247) 쿼리 검색 중: 인용절 주어 생략 문법적 허용성
# (598/1247) 쿼리 검색 중: 의존명사 고샅 두음법칙
# (599/1247) 쿼리 검색 중: 의존명사 틈 띄어쓰기
# (600/1247) 쿼리 검색 중: 부정 표현 '할래야' 어문규정 '할 수 있다'
# (601/1247) 쿼리 검색 중: 관형격 조사 생략 가능성 어미 활용
# (602/1247) 쿼리 검색 중: 의존명사 패션 외래어표기법
# (603/1247) 쿼리 검색 중: 의존명사 군 꾼 두음법칙
# (604/1247) 쿼리 검색 중: 의존명사 느러진다 늘어진다 두음법칙
# (605/1247) 쿼리 검색 중: 동사 '막다' 활용 어간 어미 '-어' 결합
# (606/1247) 쿼리 검색 중: 부사 '천천히' 띄어쓰기
# (607/1247) 쿼리 검색 중: 의존명사 데 부사격조사 부사격조사 생략 가능 여부 의존명사와 부사격조사 결합
# (608/1247) 쿼리 검색 중: 의존명사 양 량 단위표현 두음법칙
# (609/1247) 쿼리 검색 중: 의존명사 벌겋다 어근 활용 두음법칙
# (610/1247) 쿼리 검색 중: 주민자치센터 용어 선정 적정성
# (611/1247) 쿼리 검색 중: 부사 '에서' 조사 생략, 장소 명사와 결합 시 '에서' 생략 불가
# (612/1247) 쿼리 검색 중: 조사 '에서' 띄어쓰기, 동사 '마치다'의 활용, 수사 '둘' 띄어쓰기
# (613/1247) 쿼리 검색 중: 동사 '먹다' 보조동사 '께요' 어미 활용
# (614/1247) 쿼리 검색 중: 인사말 '반갑습니다' 어문규정 맞춤법
# (615/1247) 쿼리 검색 중: 문장 부호 쉼표 쉼표의 용법 주어 목적어
# (616/1247) 쿼리 검색 중: 동사 '내리다'의 활용, 어간과 어미, 맞춤법
# (617/1247) 쿼리 검색 중: 동사 '하다' 활용 어간 '하-' 뒤 '-라고' 연결
# (618/1247) 쿼리 검색 중: 동사 어간 활용 두음법칙
# (619/1247) 쿼리 검색 중: 프랑스어 외래어 표기법 소매 망슈 망시
# (620/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 동사 '벼르다'의 활용, 관형사형 어미와 '은/는'의 결합
# (621/1247) 쿼리 검색 중: 의존명사 핥- 할- 발음규칙
# (622/1247) 쿼리 검색 중: 어휘 선택 두음법칙 외래어 표기
# (623/1247) 쿼리 검색 중: 기억해냈다 기억해 냈다 용언의 보조동사 활용
# (624/1247) 쿼리 검색 중: 명사 '퍼즐' 한글 맞춤법 '맞추다'
# (625/1247) 쿼리 검색 중: 의존명사 푹하다 푸카다 한글맞춤법
# (626/1247) 쿼리 검색 중: 문장부호 쉼표 용법 문장의 명사구 경계
# (627/1247) 쿼리 검색 중: 부사 슬며시 두음법칙
# (628/1247) 쿼리 검색 중: 명령문 연결 어미 '-던지' 사용법
# (629/1247) 쿼리 검색 중: 표준어 규정 사업 용어 한자어 외래어
# (630/1247) 쿼리 검색 중: 의성어 표준표현 두음법칙
# (631/1247) 쿼리 검색 중: 헷갈리다 부사 파생 규범 표준어
# (632/1247) 쿼리 검색 중: 루쉰 노신 한자 표기 표준어 규정
# (633/1247) 쿼리 검색 중: 의존명사 바니시 바니시 영어 외래어 표기법
# (634/1247) 쿼리 검색 중: 의존명사 다행이 다행히 부사 파생 접미사
# (635/1247) 쿼리 검색 중: 의존명사 조깅 죠깅 두음법칙
# (636/1247) 쿼리 검색 중: 의존명사 콤퍼스 컴퍼스 외래어표기법
# (637/1247) 쿼리 검색 중: 의존명사 방 방위 두음법칙
# (638/1247) 쿼리 검색 중: 북 부사격조사 생략
# (639/1247) 쿼리 검색 중: 부득이 부득이하게 두음법칙
# (640/1247) 쿼리 검색 중: 문장 부정확한 높임 표현 존댓말 어미 사용
# (641/1247) 쿼리 검색 중: 의존명사 명 수사 띄어쓰기
# (642/1247) 쿼리 검색 중: 관형사 만만챦다 만만치 않다 띄어쓰기
# (643/1247) 쿼리 검색 중: 의존명사 끝 두음법칙
# (644/1247) 쿼리 검색 중: 사례 사례의 맞춤법 맞춤법 오류 사례 사례의 표기 규정
# (645/1247) 쿼리 검색 중: 의존명사 윗옷 웃옷 한자어 고유어
# (646/1247) 쿼리 검색 중: 의존명사 지 냉 두음법칙
# (647/1247) 쿼리 검색 중: 밭사돈 고유어 한자어 차이
# (648/1247) 쿼리 검색 중: 의존명사 디디다 딛다 동사어간 활용
# (649/1247) 쿼리 검색 중: 의존명사 예의 보조사 발라서 어미 활용
# (650/1247) 쿼리 검색 중: 존댓말 어미 '-겠습니다'와 반말 '아버지?' 결합, 존비법 일치 규정
# (651/1247) 쿼리 검색 중: 의존명사 섬 지명표기 고유명사
# (652/1247) 쿼리 검색 중: 문장부호 초속 30미터
# (653/1247) 쿼리 검색 중: 문장부호 사용법, 서술어 생략 금지, 문장 종결 표현
# (654/1247) 쿼리 검색 중: 부사 '갑자기' 띄어쓰기, 부사와 동사 띄어쓰기
# (655/1247) 쿼리 검색 중: 문장 어문규범 맞춤법 1910 1950
# (656/1247) 쿼리 검색 중: 여왕개미 숫개미 표준어 표준어 규정
# (657/1247) 쿼리 검색 중: 의존명사 층 두음법칙
# (658/1247) 쿼리 검색 중: 의존명사 숫막새 수막새 표준어규정
# (659/1247) 쿼리 검색 중: 의존명사 께 게 맞춤법
# (660/1247) 쿼리 검색 중: 의존명사 길 길-ㅅ 합성어
# (661/1247) 쿼리 검색 중: 조사 생략 어미 '-는데' 연결
# (662/1247) 쿼리 검색 중: 맞춤법 형만 한/형만한/형 만한 띄어쓰기
# (663/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 피동 표현의 적절한 사용, 표준어 규정 관형격 조사 생략
# (664/1247) 쿼리 검색 중: 문장부호 쉼표 사용 이유
# (665/1247) 쿼리 검색 중: 의존명사 초점 촛점 두음법칙
# (666/1247) 쿼리 검색 중: 조합하여 여러 차례의 개정을 거쳐 만들어졌다
# (667/1247) 쿼리 검색 중: 의존명사 열어젖히다 한 단어 표준어
# (668/1247) 쿼리 검색 중: 의존명사 시킴으로서 시킴으로써 맞춤법 두음법칙
# (669/1247) 쿼리 검색 중: 의존명사 것 조사 일걸 일껄 맞춤법
# (670/1247) 쿼리 검색 중: 의존명사 거라든가 거라던가 맞춤법
# (671/1247) 쿼리 검색 중: 의존명사 여부 용언 활용 어간 어미
# (672/1247) 쿼리 검색 중: 의존명사 뻐꾹이 표준어 표기
# (673/1247) 쿼리 검색 중: 동사 어간 활용 어미 '-은' 피동 표현
# (674/1247) 쿼리 검색 중: 연결어 결합 형태 표준어 규정
# (675/1247) 쿼리 검색 중: 의존명사 까짓것 맞춤법
# (676/1247) 쿼리 검색 중: 맞춤법 허위적거리며 허우적거리며 동음이의어 표준어 규정
# (677/1247) 쿼리 검색 중: 문장부호 문장 종결표현 마침표
# (678/1247) 쿼리 검색 중: 의존명사 '던지' 연결어미 어문규정
# (679/1247) 쿼리 검색 중: 의존명사 넓- 널찍하다 한글맞춤법
# (680/1247) 쿼리 검색 중: 의존명사 건 대 두음법칙
# (681/1247) 쿼리 검색 중: 의존명사 먹을 것 관형격 조사 '의' 생략 가능
# (682/1247) 쿼리 검색 중: 의존명사 디렉터리 디렉토리 한글맞춤법
# (683/1247) 쿼리 검색 중: 관형격 조사 '으로서' 띄어쓰기
# (684/1247) 쿼리 검색 중: 치아 명칭 덧니 맞춤법
# (685/1247) 쿼리 검색 중: 의존명사 과일 열거 표준어 규정
# (686/1247) 쿼리 검색 중: 시간 제한 어미 '-으니' 연결 어미 '-서' 부사 '제한' 띄어쓰기
# (687/1247) 쿼리 검색 중: 의존명사 거리 명사구 띄어쓰기
# (688/1247) 쿼리 검색 중: 의존명사 컬러 칼라 외래어 표기법
# (689/1247) 쿼리 검색 중: 의존명사 '같다' 보조형용사 '같다' 두음법칙
# (690/1247) 쿼리 검색 중: 관형격 조사 '은' 생략 가능 여부, 동사 '만들다'의 활용, 간판쟁이 맞춤법, 관형격 조사 생략 규정
# (691/1247) 쿼리 검색 중: 부사 '서서이' 맞춤법 관형사형 어미와 부사 결합 한글 맞춤법 제47항
# (692/1247) 쿼리 검색 중: 전환점으로서 전치격 조사
# (693/1247) 쿼리 검색 중: 반 협박이나 다름없는 말이었다 어문규범 부적합 수정 이유
# (694/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 호칭 뒤 높임 표현, 감탄사 활용
# (695/1247) 쿼리 검색 중: 동사 '잡다'의 활용 어미 '-아' 결합
# (696/1247) 쿼리 검색 중: 어문규범 즉 접속 표현
# (697/1247) 쿼리 검색 중: 지명 영어 한글표기 표준어규정
# (698/1247) 쿼리 검색 중: 의존명사 율 률 한글맞춤법
# (699/1247) 쿼리 검색 중: 띄어쓰기 고유명사 성명
# (700/1247) 쿼리 검색 중: 의존명사 멜론 메론 표준어표기
# (701/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 관형절 구조, 시제 표현, 성인이 된 것 실감났다 관형화 용법
# (702/1247) 쿼리 검색 중: 외래어 한글 표기 원칙 로마자 표기법
# (703/1247) 쿼리 검색 중: 의존명사 '…' 띄어쓰기
# (704/1247) 쿼리 검색 중: 의존명사 '채'의 용법, 부사 '채'와 '체' 구분, 한글 맞춤법 '채'의 쓰임
# (705/1247) 쿼리 검색 중: 관형격 조사 생략 명사 나열 명사화 표현
# (706/1247) 쿼리 검색 중: 상황시 비상 대책 두음법칙
# (707/1247) 쿼리 검색 중: 의존명사 하이라이트 하일라이트 외래어 표기법
# (708/1247) 쿼리 검색 중: 피어 어간 활용 피동표현
# (709/1247) 쿼리 검색 중: 동사 '듣다' 어간 활용 어미 '-었-' 결합
# (710/1247) 쿼리 검색 중: 의존명사 배 뱃 멀미 한자어 표기
# (711/1247) 쿼리 검색 중: 외래어 한글표기 원칙 로마자표기법
# (712/1247) 쿼리 검색 중: 의존명사 통 달려가-어미 '-게요' 맞춤법
# (713/1247) 쿼리 검색 중: 의존명사 날 수사 두음법칙
# (714/1247) 쿼리 검색 중: 공념불 고유어 한자어 구분
# (715/1247) 쿼리 검색 중: 의존명사 무우 무 두음법칙
# (716/1247) 쿼리 검색 중: 지금으로서는 어미 '-로서' 조사 '로서'
# (717/1247) 쿼리 검색 중: 외래어 표기법 미스터리
# (718/1247) 쿼리 검색 중: 조선 왕조 릉묘 지명 표기 한글 맞춤법
# (719/1247) 쿼리 검색 중: 의존명사 사정으로써 사정으로서 두음법칙
# (720/1247) 쿼리 검색 중: 문장부호 소괄호 이유
# (721/1247) 쿼리 검색 중: 의존명사 손 색깔 형용사 어간 활용 두음법칙
# (722/1247) 쿼리 검색 중: 명령문 어미 생략 오류, 명령문에는 '-어라' '-아라' 결합
# (723/1247) 쿼리 검색 중: '윗'의 한글 맞춤법, '위턱'의 표기
# (724/1247) 쿼리 검색 중: 인턴십 인턴쉽 외래어표기법
# (725/1247) 쿼리 검색 중: 조사 '래야' 어미 활용 뗄 수 없다
# (726/1247) 쿼리 검색 중: 의존명사 인센티브 인샌티브 두음법칙
# (727/1247) 쿼리 검색 중: 의존명사 한그루 관형사 붙여쓰기
# (728/1247) 쿼리 검색 중: 감탄사와 어미 '-다' 결합, 구어체 감탄사의 표기
# (729/1247) 쿼리 검색 중: 의존명사 런닝 러닝 두음법칙
# (730/1247) 쿼리 검색 중: 외래어 표기법 한글 영어 Impact
# (731/1247) 쿼리 검색 중: 동사 '찾다' 활용 어간 어미 '-고싶어' 결합
# (732/1247) 쿼리 검색 중: 관형사형 어미 '-는'의 용법, 외래어 표기법, 부사 '낯설은'의 맞춤법, 업무 명사 결합
# (733/1247) 쿼리 검색 중: 조사 결합 어문규정
# (734/1247) 쿼리 검색 중: 용언 어간 어미 되 돼 어간과 어미 구분
# (735/1247) 쿼리 검색 중: 동사 '하다' 활용 어간과 어미 결합 이닦기 맞춤법 표준어
# (736/1247) 쿼리 검색 중: 숫자와 대소문자 문장부호 표기
# (737/1247) 쿼리 검색 중: 동사 '있다' 피동 표현 표준어 규정
# (738/1247) 쿼리 검색 중: 의존명사 명사절 어절 띄어쓰기
# (739/1247) 쿼리 검색 중: 의존명사 '과도' 띄어쓰기
# (740/1247) 쿼리 검색 중: 의존명사 새 예요 체언 조사 어미
# (741/1247) 쿼리 검색 중: 저로서는 저로서 두음법칙
# (742/1247) 쿼리 검색 중: 의존명사 폐품 페품 두음법칙
# (743/1247) 쿼리 검색 중: 관형격 조사 생략 어미 연결
# (744/1247) 쿼리 검색 중: 관형사 '오늘' 띄어쓰기, 요일명 앞 띄어쓰기
# (745/1247) 쿼리 검색 중: 의존명사 속 명사구 띄어쓰기
# (746/1247) 쿼리 검색 중: 연도 표기 숫자 한글 표기 규정
# (747/1247) 쿼리 검색 중: 문장 부사어 날짜 표기 어문규정
# (748/1247) 쿼리 검색 중: 용납치 용납지 어간 활용 어미 '-지'
# (749/1247) 쿼리 검색 중: 무면허자 무면허인 관형격 조사 '의' 생략 및 명사화
# (750/1247) 쿼리 검색 중: 맞춤법 띄어쓰기 붙여쓰기
# (751/1247) 쿼리 검색 중: 에스컬레이터 손잡이 두음법칙
# (752/1247) 쿼리 검색 중: 부사 연결 어미 가만가만히
# (753/1247) 쿼리 검색 중: 의존명사 '의' 띄어쓰기, 관형격 조사 '의' 띄어쓰기 규정
# (754/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 주체 높임 표현, 동사 '취하다' 활용
# (755/1247) 쿼리 검색 중: 문장부호 사용법, 괄호와 쉼표, 문장부호의 기능
# (756/1247) 쿼리 검색 중: 의존명사 사이트 싸이트 두음법칙
# (757/1247) 쿼리 검색 중: 의존명사 빈자떡 빈대떡 표준어규정
# (758/1247) 쿼리 검색 중: 의존명사 배기 빼기 한글맞춤법
# (759/1247) 쿼리 검색 중: 의존명사 사발 띄어쓰기
# (760/1247) 쿼리 검색 중: 의존명사 목걸이 목거리 한글맞춤법
# (761/1247) 쿼리 검색 중: 부사 더욱이 더우기 한글맞춤법
# (762/1247) 쿼리 검색 중: 의존명사 케이크 명사화 두음법칙
# (763/1247) 쿼리 검색 중: 문장부호 따옴표 사용 이유
# (764/1247) 쿼리 검색 중: 의존명사 한참 명사절 연결어 두음법칙
# (765/1247) 쿼리 검색 중: 동사 '잘하다' 활용, 보조동사 '수'의 올바른 결합
# (766/1247) 쿼리 검색 중: 표준어 표기 원칙 두음법칙
# (767/1247) 쿼리 검색 중: 문장부호 질문 문장 완성법
# (768/1247) 쿼리 검색 중: 관용 표현 부둥켜 안았다 띄어쓰기
# (769/1247) 쿼리 검색 중: 부어 붓다 한글 맞춤법
# (770/1247) 쿼리 검색 중: 의존명사 메시지 메세지 맞춤법
# (771/1247) 쿼리 검색 중: 의존명사 눈 뜨이다 띄이다 맞춤법
# (772/1247) 쿼리 검색 중: 동사 '기억하다' 어간 '-하-' 뒤 '-십시오' 어미
# (773/1247) 쿼리 검색 중: 의존명사 색 색상 두음법칙
# (774/1247) 쿼리 검색 중: 의존명사 해 해해 해년 두음법칙
# (775/1247) 쿼리 검색 중: 의존명사 '아기' 띄어쓰기, 관형격 조사 '의' 띄어쓰기
# (776/1247) 쿼리 검색 중: 의존명사 점심 보조용언 못하다 띄어쓰기
# (777/1247) 쿼리 검색 중: 의존명사 씨 논뿌림 어문규정
# (778/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부 지시 표현 '이/가' 사용
# (779/1247) 쿼리 검색 중: 형용사 어근 플레시 프레시 외래어 표기법
# (780/1247) 쿼리 검색 중: 의존명사 패스 패쓰 맞춤법 두음법칙
# (781/1247) 쿼리 검색 중: 조사 결합 어미 생략 규정
# (782/1247) 쿼리 검색 중: 의존명사 발음 밸런스 표준어표기
# (783/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 관형격 조사 중첩 규정, 띄어쓰기 - 관형어 연결
# (784/1247) 쿼리 검색 중: 어간 활용 못 해 못했다 어미 활용
# (785/1247) 쿼리 검색 중: 문장부호 한국수화언어법 제4조 제1항
# (786/1247) 쿼리 검색 중: 문장부호 쉼표 용법 영조 탕평책 유래 설명
# (787/1247) 쿼리 검색 중: 1919년 3월 1일 문장부호 사용 간략 표기
# (788/1247) 쿼리 검색 중: 문장부호 인사말 인용부호
# (789/1247) 쿼리 검색 중: 외래어 표기법 도큐멘터리
# (790/1247) 쿼리 검색 중: 부사 파생 접미사 이 히
# (791/1247) 쿼리 검색 중: 의존명사 페이지 수 두음법칙
# (792/1247) 쿼리 검색 중: 문장부호 사용법, 문장부호 생략과 사용, 따옴표와 괄호 문장부호
# (793/1247) 쿼리 검색 중: 콩팥 기능 임신률 차이 없음 표준어 규정 동사 활용
# (794/1247) 쿼리 검색 중: 부사 잔뜩 올바른 한글 맞춤법
# (795/1247) 쿼리 검색 중: 의존명사 등 띄어쓰기, 접속 조사 '등' 띄어쓰기
# (796/1247) 쿼리 검색 중: 의존명사 채 조사 결합 뉘다 뉘이다
# (797/1247) 쿼리 검색 중: 의존명사 명사화 드러나다 두음법칙
# (798/1247) 쿼리 검색 중: 의존명사 콘퍼런스 컨퍼런스 외래어표기법
# (799/1247) 쿼리 검색 중: 의존명사 윗돈 웃돈 한글맞춤법 1장 1항
# (800/1247) 쿼리 검색 중: 의존명사 리 리의 띄어쓰기 거리 단위
# (801/1247) 쿼리 검색 중: 의존명사 듬북 듬뿍 한글 맞춤법
# (802/1247) 쿼리 검색 중: 조사 생략 가능 여부 어미 활용 맞춤법
# (803/1247) 쿼리 검색 중: 의존명사 재 동사 측정
# (804/1247) 쿼리 검색 중: 플래시 플래쉬 두음법칙
# (805/1247) 쿼리 검색 중: 의존명사 국 굿 한글맞춤법
# (806/1247) 쿼리 검색 중: 동사 '후회하다' 어미 '-ㄹ걸' 활용
# (807/1247) 쿼리 검색 중: 공백 연속 띄어쓰기, 숫자와 의존명사 띄어쓰기
# (808/1247) 쿼리 검색 중: 프라이팬 맞춤법 후라이팬 표기법
# (809/1247) 쿼리 검색 중: 의존명사 시설 조사로서로써 두음법칙
# (810/1247) 쿼리 검색 중: 기간 표기 띄어쓰기
# (811/1247) 쿼리 검색 중: 문장부호 물음표 쉼표 용언 활용 의문문
# (812/1247) 쿼리 검색 중: 의존명사 디렉토리 디렉터리 한글맞춤법
# (813/1247) 쿼리 검색 중: 동사 '선보이다' 어간 '선뵈' 어미 '-어야' 결합
# (814/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 침울 침음 한자어 표기, 관형격 조사 생략 규정
# (815/1247) 쿼리 검색 중: 의존명사 '개업' 한자어 고유어 결합 띄어쓰기
# (816/1247) 쿼리 검색 중: 동사 '하다' 어미 '-어요' 결합
# (817/1247) 쿼리 검색 중: 동사 '마음에 들다' 피동 표현
# (818/1247) 쿼리 검색 중: 관형사형 어미 '-은' '-는' 생략, '히끗한'의 띄어쓰기, 관형격 조사 '의' 띄어쓰기
# (819/1247) 쿼리 검색 중: 의존명사 후라이 프라이 외래어 한글표기
# (820/1247) 쿼리 검색 중: 신여성 신녀성 표준어 규정
# (821/1247) 쿼리 검색 중: 동사 '다'의 활용, 어간과 어미, 동사 '나다'의 활용
# (822/1247) 쿼리 검색 중: 의존명사 간 띄어쓰기
# (823/1247) 쿼리 검색 중: 의존명사 들 모두 두음법칙
# (824/1247) 쿼리 검색 중: 의존명사 양 량 두음법칙
# (825/1247) 쿼리 검색 중: 어간 활용 어미 연결 규칙
# (826/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 관형격 조사 생략 규정, 관형격 조사 용법
# (827/1247) 쿼리 검색 중: 부사격 조사 '-면서' 용언 어미 결합
# (828/1247) 쿼리 검색 중: 문장 부사어 연결 어미 생략 표준어 규정 대좌 돋을새김 맞춤법
# (829/1247) 쿼리 검색 중: 맞춤법 '무치다' '묻히다' 구분
# (830/1247) 쿼리 검색 중: 의존명사 때 두음법칙
# (831/1247) 쿼리 검색 중: 조사 '데도' 연결어미 '-지' 맞춤법
# (832/1247) 쿼리 검색 중: 의존명사 개구쟁이 개구장이 한글맞춤법
# (833/1247) 쿼리 검색 중: 조사 결합 잘못 잘 못 띄어쓰기
# (834/1247) 쿼리 검색 중: 의존명사 '몸'의 띄어쓰기
# (835/1247) 쿼리 검색 중: 의존명사 율 률 한자어 두음법칙
# (836/1247) 쿼리 검색 중: 명사 '보존률' 한글 맞춤법 표준어 표기
# (837/1247) 쿼리 검색 중: 용언 어간과 어미의 결합, '놀라- + -며' 활용
# (838/1247) 쿼리 검색 중: 관형사 '저'와 '접때'의 의미 차이
# (839/1247) 쿼리 검색 중: 비교급 표현 어미 활용 표준어 규정
# (840/1247) 쿼리 검색 중: 진행중 띄어쓰기 붙여쓰기
# (841/1247) 쿼리 검색 중: 육십갑자 한자어 순서 표기 어문규정
# (842/1247) 쿼리 검색 중: 문장부호 직접 인용문 괄호
# (843/1247) 쿼리 검색 중: 나레이션 내레이션 발음 표준어 규정 두음법칙
# (844/1247) 쿼리 검색 중: 의존명사 깡충깡충 뛰다 어근 두음법칙
# (845/1247) 쿼리 검색 중: 의존명사 넓이 널찍한 두음법칙
# (846/1247) 쿼리 검색 중: 의존명사 샤프 샾 외래어표기법
# (847/1247) 쿼리 검색 중: 의존명사 '말' '한국말' 띄어쓰기 관형격 조사 '의' 띄어쓰기
# (848/1247) 쿼리 검색 중: 의존명사 품속 안기다 어미 표현
# (849/1247) 쿼리 검색 중: 의존명사 소리 명사화 두음법칙
# (850/1247) 쿼리 검색 중: 존재 표현 '-에 계신-' 어미 활용
# (851/1247) 쿼리 검색 중: 조동사 '하지' 생략 가능성 어미 활용
# (852/1247) 쿼리 검색 중: 의존명사 '-대' '-데' 용법 관형격 조사 '의' 생략 구어체 '-컨대' 표준어 '-다고 생각한다 부사어 '-지' 연결어미
# (853/1247) 쿼리 검색 중: 의존명사 액세서리 외래어 표기법
# (854/1247) 쿼리 검색 중: 의존명사 마스크 매스크 두음법칙
# (855/1247) 쿼리 검색 중: 조사 생략 어미 활용 표준어 규정 주체 높임 표현
# (856/1247) 쿼리 검색 중: 의존명사 소리 두음법칙
# (857/1247) 쿼리 검색 중: 고유명사 표기 원칙 국제기구명 영문 표기
# (858/1247) 쿼리 검색 중: 문장 부호 사용 규정 주어 부사어 문장 구조
# (859/1247) 쿼리 검색 중: 관형사 '샛' 한글 맞춤법 음절 생략 규정
# (860/1247) 쿼리 검색 중: 윈도우 보안 설정 두음법칙
# (861/1247) 쿼리 검색 중: 용언 과거시제 어간 활용 어미 '-았-/-었-'
# (862/1247) 쿼리 검색 중: 관형사 형용사 어간 활용 어미 두음법칙
# (863/1247) 쿼리 검색 중: 의존명사 쪽 방향 두음법칙
# (864/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 동물 이름 표기법, 외래어 및 고유어 결합 표기
# (865/1247) 쿼리 검색 중: 숫자 표기법 한글 숫자 띄어쓰기
# (866/1247) 쿼리 검색 중: 감탄사 어미 조사 붙임표
# (867/1247) 쿼리 검색 중: 명사 '가슴'의 올바른 표기 어문규정 표준어 맞춤법
# (868/1247) 쿼리 검색 중: 외래어 표기법 다코야키 타코야키
# (869/1247) 쿼리 검색 중: 문장부호 사용 규정, 문장 종결표현, 온점(마침표) 사용
# (870/1247) 쿼리 검색 중: 의존명사 말티즈 표준어표기
# (871/1247) 쿼리 검색 중: 의존명사 주스 쥬스 외래어표기법
# (872/1247) 쿼리 검색 중: 관형사 숫 사자 머리 갈기 맞춤법 표준어 표기
# (873/1247) 쿼리 검색 중: 의존명사 마스크 마슼 외래어 표기법
# (874/1247) 쿼리 검색 중: 동사 '오다' 활용 어간 '오-'에 명령형 어미 결합
# (875/1247) 쿼리 검색 중: 도로교통법위반 맞춤법 표준어 규정 음주운전
# (876/1247) 쿼리 검색 중: 관형사형 어미 '-았-/-었-' 활용
# (877/1247) 쿼리 검색 중: 조사 결합 위치 띄어쓰기
# (878/1247) 쿼리 검색 중: 의존명사 매트리스 맷릭스 두음법칙
# (879/1247) 쿼리 검색 중: 서술격 조사 '이다' 생략 가능성 어문규정
# (880/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 감탄 표현 어미 활용, 피로 명사 활용 및 꾸밈
# (881/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 색채어 수식 구조, 비유 표현 어문 규범
# (882/1247) 쿼리 검색 중: 동사 '치르다' 어간 활용
# (883/1247) 쿼리 검색 중: 의존명사 점장 점쟁이 한자어 고유어
# (884/1247) 쿼리 검색 중: 의문문 어미 '-에요' 어미 활용 표준어 규정
# (885/1247) 쿼리 검색 중: 의존명사 돈 단어의 결합 두음법칙
# (886/1247) 쿼리 검색 중: 의존명사 율 률 한자어 표기
# (887/1247) 쿼리 검색 중: 관형사형 어미 '-은' '-는' 사용, 부정적 의미 관형사형과 '눈'의 결합, 탐탁지 않은 탐탁찮은 맞춤법
# (888/1247) 쿼리 검색 중: 공손한 인사말 존댓말 어미 '-습니다'
# (889/1247) 쿼리 검색 중: 용언 활용 피동 표현 맞춤법
# (890/1247) 쿼리 검색 중: 관형사형 어미 '-은'의 올바른 활용, 부사 '변변치 않은
# (891/1247) 쿼리 검색 중: 문장부호 병기 괄호 영어 맞춤법
# (892/1247) 쿼리 검색 중: 의존명사 '첨에' 한글 맞춤법
# (893/1247) 쿼리 검색 중: 프랑스어 외래어 표기법 두음법칙
# (894/1247) 쿼리 검색 중: 의존명사 따위 띄어쓰기
# (895/1247) 쿼리 검색 중: 동기 표현 강조 조사 '그럼' 중복
# (896/1247) 쿼리 검색 중: 의존명사 녘 두음법칙
# (897/1247) 쿼리 검색 중: 문장부호 쉼표 마침표 문장 경계
# (898/1247) 쿼리 검색 중: 의존명사 오똑이 표준어사용
# (899/1247) 쿼리 검색 중: 프라이팬 표준어 맞춤법
# (900/1247) 쿼리 검색 중: 존댓말 과거시제 '-았/었-' 활용
# (901/1247) 쿼리 검색 중: 의존명사 또아리 또아리 또아리 표준어 표준어 규정
# (902/1247) 쿼리 검색 중: 의존명사 '날' 띄어쓰기 두음법칙
# (903/1247) 쿼리 검색 중: 부딪히다 부딪치다 능동 피동
# (904/1247) 쿼리 검색 중: 장음 표기 규정 말(馬) 말(言) 음절의 장단
# (905/1247) 쿼리 검색 중: 조사 '부터' 띄어쓰기
# (906/1247) 쿼리 검색 중: 어미 '-되요'의 올바른 활용
# (907/1247) 쿼리 검색 중: 의존명사 후라이 프라이 외래어 한글표기
# (908/1247) 쿼리 검색 중: 십월 시월 표준어 규정
# (909/1247) 쿼리 검색 중: 의존명사 명사합성어 한글맞춤법
# (910/1247) 쿼리 검색 중: 의존명사 안 띄어쓰기 합성어
# (911/1247) 쿼리 검색 중: 명사 '차값' 띄어쓰기
# (912/1247) 쿼리 검색 중: 의존명사 지 치 두음법칙
# (913/1247) 쿼리 검색 중: 명사 '기름' 띄어쓰기, '기름 기' → '기름이'
# (914/1247) 쿼리 검색 중: 의존명사 '걸' 조사 결합 띄어쓰기
# (915/1247) 쿼리 검색 중: 의존명사 정답 맞히다 맞추다
# (916/1247) 쿼리 검색 중: 지시대명사 지시어 띄어쓰기
# (917/1247) 쿼리 검색 중: 의존명사 낫또 낫토 한글맞춤법 외래어표기
# (918/1247) 쿼리 검색 중: 금지표현 어미 생략 부정표현
# (919/1247) 쿼리 검색 중: 영문 고유명사 한글표기 외래어표기법
# (920/1247) 쿼리 검색 중: 의존명사 둘째 두째 두음법칙
# (921/1247) 쿼리 검색 중: 의존명사 같은 조사 결합 어근 형태 두음법칙
# (922/1247) 쿼리 검색 중: 의존명사 명사화접 '-(으)ㅁ' 용법, 체언 접미사 '-(으)ㅁ' 어문 규범
# (923/1247) 쿼리 검색 중: 의존명사 누 루 두음법칙
# (924/1247) 쿼리 검색 중: 의존명사 '들' 조사 결합 명사 '일'과 의존명사 '들' 결합 조사 '은/는' 결합 체언과 의존명사 '들'의 결합 규정
# (925/1247) 쿼리 검색 중: 탑비예요 맞춤법 용언 어미
# (926/1247) 쿼리 검색 중: 조사 어미 연결 어미 '-느라고'
# (927/1247) 쿼리 검색 중: 존댓말과 반말 혼용, 존댓말 일관성, 존비법 일치
# (928/1247) 쿼리 검색 중: 의존명사 팸플릿 팜플릿 외래어표기법
# (929/1247) 쿼리 검색 중: 조사 '우리'의 띄어쓰기
# (930/1247) 쿼리 검색 중: 문장부호 초속 100미터
# (931/1247) 쿼리 검색 중: 의존명사 나무 두음법칙
# (932/1247) 쿼리 검색 중: 의존명사 달달이 월별 반복부사 월
# (933/1247) 쿼리 검색 중: 띄어쓰기 연결어 시간부사
# (934/1247) 쿼리 검색 중: 의존명사 리더 리다 한자어 고유어
# (935/1247) 쿼리 검색 중: 의존명사 숫- 두음법칙
# (936/1247) 쿼리 검색 중: 마침표 사용법 표준어 규정 61항
# (937/1247) 쿼리 검색 중: 관형사형 어미 '-에' 생략 루각 루각 루각 한자어 한자어
# (938/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 서술격 조사 '이다' 띄어쓰기, 수식어와 피수식어 거리, 관형화 구성 띄어쓰기
# (939/1247) 쿼리 검색 중: 지명 접미사 구 자음연쇄 줄임표기 어문규정
# (940/1247) 쿼리 검색 중: 남존여비 남존녀비 한자어 표준어 규정
# (941/1247) 쿼리 검색 중: 의존명사 콧배기 콧배기 맞춤법
# (942/1247) 쿼리 검색 중: 관형사 '한' 띄어쓰기, 관형사와 명사 띄어쓰기
# (943/1247) 쿼리 검색 중: 명사 복합어 합성어 접미사 슬러시
# (944/1247) 쿼리 검색 중: 용언 어간 어미 연결 표준어 규정 불규칙 활용
# (945/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 고유명사 띄어쓰기, 인명 띄어쓰기, 문장 부호 '(', ')' 사용
# (946/1247) 쿼리 검색 중: 의존명사 값 값의쓰임 두음법칙
# (947/1247) 쿼리 검색 중: 의존명사 사람 인 두음법칙
# (948/1247) 쿼리 검색 중: 의존명사 시간 명사구 띄어쓰기
# (949/1247) 쿼리 검색 중: 의존명사 온데 간데 없이 두음법칙
# (950/1247) 쿼리 검색 중: 동사 '걱정하다' 활용, 명사 '쓸데없는' 띄어쓰기
# (951/1247) 쿼리 검색 중: 의존명사 팔일 한글맞춤법
# (952/1247) 쿼리 검색 중: 용언 어간 어미 아닌지 예요
# (953/1247) 쿼리 검색 중: 측정 가능성 어문 규범 측정가능한가요
# (954/1247) 쿼리 검색 중: 부사 '얇다란' 표준어 '얇은' 형용사 활용
# (955/1247) 쿼리 검색 중: 공동격 조사 '와'의 올바른 사용, 명사 '경로당'의 표기, 주민들과 사할린 동포 어르신들의 호칭 및 조사 사용
# (956/1247) 쿼리 검색 중: 용언 어간 활용 어미 '-게' 부정 표현
# (957/1247) 쿼리 검색 중: 용언 활용 보조사 '대로' 띄어쓰기
# (958/1247) 쿼리 검색 중: 동사 '흘끔대다' 활용, 시제 및 조사 사용
# (959/1247) 쿼리 검색 중: 의문문 어미 '-(으)시-', 존댓말 사용
# (960/1247) 쿼리 검색 중: 외래어 표기법 콜라보레이션 컬래버레이션
# (961/1247) 쿼리 검색 중: 의존명사 숫자 한자어 차례 순서 두음법칙
# (962/1247) 쿼리 검색 중: 관형사형 어미 '-(으)ㅁ'과 결합한 명사 표기
# (963/1247) 쿼리 검색 중: 어미 '-어' 활용 감탄형 어미 표기
# (964/1247) 쿼리 검색 중: 맞춤법 사탕을 준다든데 사탕을 준다던데 어미 활용
# (965/1247) 쿼리 검색 중: 관형사 '설립된' 띄어쓰기
# (966/1247) 쿼리 검색 중: 의존명사 옷걸이 옷거리 두음법칙
# (967/1247) 쿼리 검색 중: 동사 '돌아가다' 활용 어간 어미 '-렴' '-란다' 존댓말 존대표현
# (968/1247) 쿼리 검색 중: 동사 '맡다'의 활용, 보조동사 '하다'의 결합, 존댓말 어미, 명사 '발표자'의 띄어쓰기
# (969/1247) 쿼리 검색 중: 협동 정신 즉 서로 마음 힘 하나로 합하는 것이 필요하다 관형격 조사 생략
# (970/1247) 쿼리 검색 중: 문장 부사어 시기 표현 날짜 표기 어문규정
# (971/1247) 쿼리 검색 중: 관형사 '그'의 띄어쓰기, 시간 표현 '그 다음 주' 띄어쓰기 규정
# (972/1247) 쿼리 검색 중: 공문서 날짜 한글 표기 규정, 연휴 기간 표기법, 공문서 휴관 안내 문장 맞춤법
# (973/1247) 쿼리 검색 중: 의존명사 시 조사 결합 띄어쓰기
# (974/1247) 쿼리 검색 중: 관형격 조사 '의' 띄어쓰기
# (975/1247) 쿼리 검색 중: 문장부호 절 표기 규정
# (976/1247) 쿼리 검색 중: 의존명사 걸 조사 어문규정
# (977/1247) 쿼리 검색 중: 의존명사 사인 싸인 두음법칙
# (978/1247) 쿼리 검색 중: 의존명사 마리 수의 띄어쓰기
# (979/1247) 쿼리 검색 중: 의존명사 보타이 보우타이 외래어표기법
# (980/1247) 쿼리 검색 중: 의존명사 대싸리 댑싸리 표준어 규정
# (981/1247) 쿼리 검색 중: 동사 중복 활용 과거시제 어미
# (982/1247) 쿼리 검색 중: 부정표현 연결어미 띄어쓰기
# (983/1247) 쿼리 검색 중: 용언 어간 활용 어미 '-(으)ㄴ가' 연결 어미 '-(으)ㄴ가' 올바른 활용
# (984/1247) 쿼리 검색 중: 의존명사 '지우다' 어간 활용 두음법칙
# (985/1247) 쿼리 검색 중: 의존명사 병아리 암 평 두음법칙
# (986/1247) 쿼리 검색 중: 용언 어간 어미 활용 맛이 나다
# (987/1247) 쿼리 검색 중: 의존명사 핑계 핑게 두음법칙
# (988/1247) 쿼리 검색 중: '하고' 조사 사용 규정, 의존명사 '만나다' 활용, 간접 인용문 어미
# (989/1247) 쿼리 검색 중: 조사 결합 어미 생략 맞춤법
# (990/1247) 쿼리 검색 중: 문장부호 명령문 종결표현
# (991/1247) 쿼리 검색 중: 관형격 조사 '던'의 올바른 사용법
# (992/1247) 쿼리 검색 중: 문장 부정확성 사후 관리 대상 해당 기준
# (993/1247) 쿼리 검색 중: 외래어 표기법 보디로션
# (994/1247) 쿼리 검색 중: 용언 어간과 체언 결합 어미 '-이야' 활용
# (995/1247) 쿼리 검색 중: 의존명사 지 치 용언 활용 어간 어미
# (996/1247) 쿼리 검색 중: 의존명사 스커트 한글맞춤법
# (997/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 어미 활용 명사형 어미
# (998/1247) 쿼리 검색 중: 용언 연결어미 '-어줄' 활용
# (999/1247) 쿼리 검색 중: 문장 부호 띄어쓰기 수학 용어 표기
# (1000/1247) 쿼리 검색 중: 의존명사 길다란 기다란 형용사 어근 두음법칙
# (1001/1247) 쿼리 검색 중: 의존명사 빼기 배기 한자어 표준어 규정
# (1002/1247) 쿼리 검색 중: 의존명사 걸 어미 활용
# (1003/1247) 쿼리 검색 중: 어간 어미 활용 하시- 하시요 하시오
# (1004/1247) 쿼리 검색 중: 동사 '못하다' 연결 어미 '-(으)니' '-(으)니까' '-(으)므로' 활용
# (1005/1247) 쿼리 검색 중: 관형사형 어미 '-던'의 활용, 동사 '당황하다'의 피동 표현
# (1006/1247) 쿼리 검색 중: 의존명사 명사화접 '-장이' '-쟁이' 표준어 규정
# (1007/1247) 쿼리 검색 중: '뵈다' 어간 '뵈' 뒤 '-어요' 어미 결합
# (1008/1247) 쿼리 검색 중: 고법古法 한자어 고유명사 표기 원칙
# (1009/1247) 쿼리 검색 중: 동사 '되다' 활용 어간 어미
# (1010/1247) 쿼리 검색 중: 의존명사 덩굴 덩쿨 맞춤법
# (1011/1247) 쿼리 검색 중: 관형사 깊히 부사 깊이 띄어쓰기
# (1012/1247) 쿼리 검색 중: 의존명사 대부흥 두음법칙
# (1013/1247) 쿼리 검색 중: 참다 참어라 어간 어미 활용
# (1014/1247) 쿼리 검색 중: 의존명사 시간 명사화 태타임 두음법칙
# (1015/1247) 쿼리 검색 중: 동사 '하다' 활용 피동 표현 어간 어미 결합 표준어 규정
# (1016/1247) 쿼리 검색 중: 문장부호 쉼표 생략 이유 문장 연결
# (1017/1247) 쿼리 검색 중: '햇님' 표준어 규정 고유어 한글 맞춤법
# (1018/1247) 쿼리 검색 중: 동사 '없어지다' 활용, 피동 표현, 어간과 어미 결합
# (1019/1247) 쿼리 검색 중: 의존명사 광 관형격 조사 '의' 생략
# (1020/1247) 쿼리 검색 중: 관형사 '이'와 '이란'의 띄어쓰기, 수 관형사와 '이란'의 결합, 시간 명사 '년'의 띄어쓰기
# (1021/1247) 쿼리 검색 중: 어간 활용 어미 '-쟎니' 어문규정 맞춤법
# (1022/1247) 쿼리 검색 중: 의존명사 '이러케' 맞춤법 '이렇게'
# (1023/1247) 쿼리 검색 중: 되세요 돼세요 어미 '-세요' 활용
# (1024/1247) 쿼리 검색 중: 의존명사 량 양 두음법칙
# (1025/1247) 쿼리 검색 중: 용언 활용 보조사 '됐다' 어간 어미 맞춤
# (1026/1247) 쿼리 검색 중: 외래어 표기법 삿포로
# (1027/1247) 쿼리 검색 중: 의존명사 콘텐츠 컨텐츠 외래어표기법
# (1028/1247) 쿼리 검색 중: 날짜 표기 숫자 한글 영문 띄어쓰기
# (1029/1247) 쿼리 검색 중: 부사 '부터' 조사 '의' 결합 어근 '먹다' 부사격 조사 '부' 결합 맞춤법 '뭐부터'
# (1030/1247) 쿼리 검색 중: 의존명사 번 횟수 한 번 한번 띄어쓰기
# (1031/1247) 쿼리 검색 중: 단언컨대 두음법칙
# (1032/1247) 쿼리 검색 중: 의존명사 씌다 쓰다 한글맞춤법
# (1033/1247) 쿼리 검색 중: 의존명사 디지털 디지탈 한글맞춤법
# (1034/1247) 쿼리 검색 중: 부사 '빨리' 반복, 강조 표현, 어문 규범 반복 사용
# (1035/1247) 쿼리 검색 중: 표준 저항기 비교 기준 어문 규범 맞춤법 오류
# (1036/1247) 쿼리 검색 중: 동사 '쓰다' 활용 어간 명사화 어문규정
# (1037/1247) 쿼리 검색 중: 의존명사 지 치 두음법칙
# (1038/1247) 쿼리 검색 중: 문장부호 인용부호 쉼표 사용 이유
# (1039/1247) 쿼리 검색 중: 조사 '은/는' 어미 '-구나' 구어체 표준어 활용
# (1040/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 부사어 구성, 속어 및 비표준어 사용
# (1041/1247) 쿼리 검색 중: 의존명사 밑 두음법칙
# (1042/1247) 쿼리 검색 중: 용언 어간 활용 피동 표현 '이르키다' 잘못된 활용
# (1043/1247) 쿼리 검색 중: 관형사 '일찍' 띄어쓰기, 부사와 동사 띄어쓰기
# (1044/1247) 쿼리 검색 중: 의존명사 블라우스 브라우스 외래어 표기법
# (1045/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 지시 표현 '그'의 용법, 서술어 '주목되다' 피동 표현, 관형사 '매우'의 위치, 조사 '에서'의 올바른 사용, 명사 '희귀한' 띄어쓰기
# (1046/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 외래어 표기법, 복수 표기 '-들'
# (1047/1247) 쿼리 검색 중: 하니바람 띄어쓰기 합성어 고유어 한글 맞춤법
# (1048/1247) 쿼리 검색 중: 조사 어미 연결어미 띄어쓰기
# (1049/1247) 쿼리 검색 중: 동사 '주다' 활용 '-아 주다' 어미, 맞춤법 '-께요'
# (1050/1247) 쿼리 검색 중: 외래어 표기법 카디건 가디건
# (1051/1247) 쿼리 검색 중: 지시어 '그들' 대명사 중복 지시대명사 '그들'과 '사이'의 어문 규범
# (1052/1247) 쿼리 검색 중: 입헌군주제 표기 맞춤법 '있겠다'의 올바른 표현
# (1053/1247) 쿼리 검색 중: 관형사 월간 명사 지 명사화 조사이다 어문규정
# (1054/1247) 쿼리 검색 중: 의존명사 해돋이 해도지 두음법칙
# (1055/1247) 쿼리 검색 중: 의존명사 연도 년도 두음법칙
# (1056/1247) 쿼리 검색 중: 동사 어간 활용 어미 결합 못한다 못 한다고
# (1057/1247) 쿼리 검색 중: 의존명사 무늬 두음법칙
# (1058/1247) 쿼리 검색 중: 동사 '맞히다' '맞추다' 구분
# (1059/1247) 쿼리 검색 중: 부사 '들릴만큼' 띄어쓰기, 부사와 조사 '만큼' 띄어쓰기
# (1060/1247) 쿼리 검색 중: 의존명사 넓다 널따랗다 넓다랗다 형용사 어간 음운변동
# (1061/1247) 쿼리 검색 중: 의존명사 띠 띄 두음법칙
# (1062/1247) 쿼리 검색 중: 의존명사 녹록- 녹록지 두음법칙
# (1063/1247) 쿼리 검색 중: 의존명사 전화 연결 동사 활용
# (1064/1247) 쿼리 검색 중: 의존명사 박 뒤웅박 두음법칙
# (1065/1247) 쿼리 검색 중: 조사 결합 형태 어미 띄어쓰기
# (1066/1247) 쿼리 검색 중: 의존명사 쟁이 쟁이 두음법칙
# (1067/1247) 쿼리 검색 중: 의존명사 스팟 스폿 외래어 표기법
# (1068/1247) 쿼리 검색 중: 동사 '이다'의 피동 표현, 어간 활용, 형용사화
# (1069/1247) 쿼리 검색 중: 의존명사 아지랑이 아지랭이 두음법칙
# (1070/1247) 쿼리 검색 중: 의존명사 여덟 열여덟 숫자합성어
# (1071/1247) 쿼리 검색 중: 동사 '조심' 명사화 어문규정
# (1072/1247) 쿼리 검색 중: 부사 곰곰이 생각해 보았다
# (1073/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능 여부, 명사 '무늬' 띄어쓰기, 동사 '입다' 과거 활용
# (1074/1247) 쿼리 검색 중: 의존명사 '로써' '로서' 차이
# (1075/1247) 쿼리 검색 중: 문장부호 용례 사전적 의미 괄호
# (1076/1247) 쿼리 검색 중: 문장부호 시간표현
# (1077/1247) 쿼리 검색 중: 존댓말 어미 '-겠-' 결합 '-을게요' 맞춤법
# (1078/1247) 쿼리 검색 중: 외래어 한글 표기 원칙 두음법칙
# (1079/1247) 쿼리 검색 중: 부사 '열심히'
# (1080/1247) 쿼리 검색 중: 의존명사 쯤 두음법칙
# (1081/1247) 쿼리 검색 중: 어문규정 어휘선택 수막새 암기와 한글맞춤법
# (1082/1247) 쿼리 검색 중: 관형격 조사 '에' 생략 가능 여부, 피동 표현 '-이다' 어미 활용, 동사 '쐬다' 활용형
# (1083/1247) 쿼리 검색 중: 의존명사 하나로서 하나로써 조사 용법
# (1084/1247) 쿼리 검색 중: '슈퍼마켓' 두음법칙 표준어
# (1085/1247) 쿼리 검색 중: 소유격 조사 '예요'의 사용, 소유격 표현 규정
# (1086/1247) 쿼리 검색 중: 부사 파생 접미사 -히 -하게 의미 중복
# (1087/1247) 쿼리 검색 중: 명사 '딱지' 활용 어미 맞춤 표준어 규정
# (1088/1247) 쿼리 검색 중: 관형사형 어미 '-은'의 용법, 부사어의 위치, 형용사 활용 '-스럽다'의 쓰임, 한자어 접미사 '-스럽다'의 활용, 관형격 조사 '의'의 중복 사용
# (1089/1247) 쿼리 검색 중: 구분 기호 띄어쓰기 연속 날짜 표기
# (1090/1247) 쿼리 검색 중: 외래어 표기법 페어플레이 두음법칙
# (1091/1247) 쿼리 검색 중: 의존명사 단백질 명사구 조립 규정
# (1092/1247) 쿼리 검색 중: 맞춤법 반듯이 반듯이로뛰어쓰기 올바른표현
# (1093/1247) 쿼리 검색 중: 연속된 날짜 표기 숫자 한글화 날짜 띄어쓰기
# (1094/1247) 쿼리 검색 중: 외래어 표기법 셰이커
# (1095/1247) 쿼리 검색 중: 의존명사 클래스 클래스어 표준어표기
# (1096/1247) 쿼리 검색 중: '입사 년도' 표기법 어문규정
# (1097/1247) 쿼리 검색 중: 의문문 어미 '-든' 맞춤법
# (1098/1247) 쿼리 검색 중: 조사 생략 가능성 어미 활용
# (1099/1247) 쿼리 검색 중: 엔진 두음법칙
# (1100/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 관형격 조사 생략 규정, 관형격 조사 생략과 자연스러운 표현
# (1101/1247) 쿼리 검색 중: 의존명사 래티놀 레티놀 외래어 표기법
# (1102/1247) 쿼리 검색 중: 동사 '하다' 활용 돼지 표준어 맞춤법
# (1103/1247) 쿼리 검색 중: 외래어 표기법 보트
# (1104/1247) 쿼리 검색 중: 의존명사 돗자리 돋자리 표준어표기
# (1105/1247) 쿼리 검색 중: 스폰서 스펀서 외래어 표기법
# (1106/1247) 쿼리 검색 중: 의존명사 '값' 띄어쓰기, 수량 표현 '드는' 맞춤법
# (1107/1247) 쿼리 검색 중: 관형사형 어미 '-아서' '-아서'
# (1108/1247) 쿼리 검색 중: 동사 '생각하다' 어간 활용 어미 '-아보렴'
# (1109/1247) 쿼리 검색 중: 문장부호 물음표 쉼표 문장 종결자
# (1110/1247) 쿼리 검색 중: 의존명사 타겟 타깃 한글맞춤법 두음법칙
# (1111/1247) 쿼리 검색 중: 의존명사 개구리 두음법칙
# (1112/1247) 쿼리 검색 중: 의존명사 형용사구 관형절 두음법칙
# (1113/1247) 쿼리 검색 중: 맞춤법 유예 유예 기간 띄어쓰기
# (1114/1247) 쿼리 검색 중: 의존명사 본따서 본뜨다 어근 비교
# (1115/1247) 쿼리 검색 중: 반말 존댓말 호칭 어미 사용 규정
# (1116/1247) 쿼리 검색 중: 로브스터 로브스터 두음법칙
# (1117/1247) 쿼리 검색 중: 의존명사 시구 시귀 한자어 표준어
# (1118/1247) 쿼리 검색 중: 문장부호 명사화 한글 맞춤법 제40항
# (1119/1247) 쿼리 검색 중: 의존명사 닁큼 닝큼 두음법칙
# (1120/1247) 쿼리 검색 중: 의존명사 초점 촛점 두음법칙
# (1121/1247) 쿼리 검색 중: 동사 '쓰다' 활용 어간 명령형 '-(으)세요' 결합
# (1122/1247) 쿼리 검색 중: 의존명사 믹서 믹사 외래어 표기법
# (1123/1247) 쿼리 검색 중: '핼러윈' '할로윈' 외래어 표기법
# (1124/1247) 쿼리 검색 중: 의존명사 꺼리 명사화표현 두음법칙
# (1125/1247) 쿼리 검색 중: 문장부호 쉼표 따옴표 문장부호규정
# (1126/1247) 쿼리 검색 중: 문장부호 연결형 어미 쉼표
# (1127/1247) 쿼리 검색 중: 퀵서비스 올바른 표기법
# (1128/1247) 쿼리 검색 중: 문장부호 용례 폐쇄 괄호
# (1129/1247) 쿼리 검색 중: 부사 '그냥' 띄어쓰기, 부사와 동사 띄어쓰기
# (1130/1247) 쿼리 검색 중: 조사 결합 오용 어미 활용 복합어 맞춤법
# (1131/1247) 쿼리 검색 중: 의존명사 패인 팬 두음법칙
# (1132/1247) 쿼리 검색 중: 외래어 한글표기 푸시 푸쉬 두음법칙
# (1133/1247) 쿼리 검색 중: 의존명사 빛 색채명사 두음법칙
# (1134/1247) 쿼리 검색 중: 조사 어미 활용 맞춤법
# (1135/1247) 쿼리 검색 중: '챔피언' 표준어 맞춤법
# (1136/1247) 쿼리 검색 중: 문장 부정 표현 어미 '-라면' '-에선' 어문규정
# (1137/1247) 쿼리 검색 중: '컨닝' '표준어 표기'
# (1138/1247) 쿼리 검색 중: 동사 '주다' 어간 활용 어미 '-ㄹ께' 맞춤법
# (1139/1247) 쿼리 검색 중: 존댓말 어미 '-면' 활용, 존댓말 '-겠-' 어미 활용, 존댓말 '-봬면' 맞춤법
# (1140/1247) 쿼리 검색 중: 교통사고 구조차량 두음법칙
# (1141/1247) 쿼리 검색 중: 동사 '떠나다' 활용 어간 '-아야' 연결, 어미 '-는' 올바른 사용, 형용사 활용, 감탄사와 어미 결합
# (1142/1247) 쿼리 검색 중: 띄어쓰기 관형격 조사 '의' 띄어쓰기, 관형어 구조, 조사 띄어쓰기
# (1143/1247) 쿼리 검색 중: 의존명사 센터 명사화표현
# (1144/1247) 쿼리 검색 중: 의존명사 돐 돌 맞춤법 표준어 규정
# (1145/1247) 쿼리 검색 중: 어미 '-을지어다' 어법 '-을찌어다' 어미 활용
# (1146/1247) 쿼리 검색 중: 관형사 잘생기다 표준어 표기 잘생겼다
# (1147/1247) 쿼리 검색 중: 의존명사 '잎' '잎아리' 표준어 규정
# (1148/1247) 쿼리 검색 중: 서술격 조사 '이다' 생략, 존댓말 어미 오류, 명령형 어미 사용
# (1149/1247) 쿼리 검색 중: 의존명사 가지 연 걸리다 활용
# (1150/1247) 쿼리 검색 중: 관형격 조사 '의' 생략, 서술어 시제 일치, 주어-서술어 호응, 수식어 위치, 맞춤법 '장'의 용법
# (1151/1247) 쿼리 검색 중: 의존명사 윗옷 웃옷 한자어 고유어
# (1152/1247) 쿼리 검색 중: 서술격 조사 '입니다' 어미 활용 표준어 규정
# (1153/1247) 쿼리 검색 중: 시간 표현 한글 맞춤법 숫자와 어미 결합
# (1154/1247) 쿼리 검색 중: 의존명사 '짤찌라도' 어미 '-라도' 연결
# (1155/1247) 쿼리 검색 중: 의존명사 메니큐어 매니큐어 외래어표기법
# (1156/1247) 쿼리 검색 중: 의존명사 벤처 벤처기업 두음법칙
# (1157/1247) 쿼리 검색 중: 의존명사 걸 껄 맞춤법
# (1158/1247) 쿼리 검색 중: 의존명사 '해당' 띄어쓰기 표준어 규정
# (1159/1247) 쿼리 검색 중: 존댓말 어미 '-습니다' 사용
# (1160/1247) 쿼리 검색 중: 관형사 흔하디 흔한 관형사 생략 가능성, 중복 표현
# (1161/1247) 쿼리 검색 중: 외래어 표기법 솔루션 설루션
# (1162/1247) 쿼리 검색 중: 의존명사 지식 명사구 결합
# (1163/1247) 쿼리 검색 중: 동사 '토닥이다' 활용, 피동 표현, 어간 접미사
# (1164/1247) 쿼리 검색 중: 조사 어미 활용 동사 활용 쳐서 처서
# (1165/1247) 쿼리 검색 중: 문장부호 문장종결표현 마침표 이유
# (1166/1247) 쿼리 검색 중: 동사 '확인하다' 활용 어간 어미 결합
# (1167/1247) 쿼리 검색 중: 의존명사 만 띄어쓰기 만의 쓰임새
# (1168/1247) 쿼리 검색 중: 존댓말 어미 '-아야 한다' 활용
# (1169/1247) 쿼리 검색 중: 외래어 표기법 애플리케이션
# (1170/1247) 쿼리 검색 중: 관형사 숫자 한글 표기 규정
# (1171/1247) 쿼리 검색 중: 의존명사 타워 두음법칙
# (1172/1247) 쿼리 검색 중: 의존명사 카메라 캐머라 두음법칙
# (1173/1247) 쿼리 검색 중: 의존명사 치프멍크 칩멍크 외래어 표기법
# (1174/1247) 쿼리 검색 중: 공백 띄어쓰기 맞춤법 붙여쓰기
# (1175/1247) 쿼리 검색 중: 의존명사 '째' 띄어쓰기
# (1176/1247) 쿼리 검색 중: 문장부호 쉼표 용언 연결 문장 경계
# (1177/1247) 쿼리 검색 중: 부사 솔직이 관형사형 어미 결합 표준어 규정
# (1178/1247) 쿼리 검색 중: 동사 '바라다' 어미 '-아요' 결합
# (1179/1247) 쿼리 검색 중: 문장 부호 용례, 문장 내 쉼표(콤마) 사용, 부속어 나열, 띄어쓰기, 표준 부속어 표기
# (1180/1247) 쿼리 검색 중: 의존명사 특혜 특헤 한글맞춤법
# (1181/1247) 쿼리 검색 중: 시침 푼침 시간 표현 어문규정
# (1182/1247) 쿼리 검색 중: '프라이드 치킨' 표준어 표기
# (1183/1247) 쿼리 검색 중: 의존명사 강낭콩 강남콩 두음법칙
# (1184/1247) 쿼리 검색 중: 의존명사 날 어미 활용 사흘날
# (1185/1247) 쿼리 검색 중: 지명 한글표기 표준어규정
# (1186/1247) 쿼리 검색 중: 의존명사 쇼핑 셔핑 외래어표기법
# (1187/1247) 쿼리 검색 중: 부정 표현 '안된다' 띄어쓰기
# (1188/1247) 쿼리 검색 중: 의존명사 어미 에미 처가 두음법칙
# (1189/1247) 쿼리 검색 중: 금지표현 어미 '-안 -돼' 맞춤법
# (1190/1247) 쿼리 검색 중: 작부 체계 두음법칙 표준어 규정
# (1191/1247) 쿼리 검색 중: 의존명사 손님 명사화표현
# (1192/1247) 쿼리 검색 중: 의존명사 쉼표 띄어쓰기 붙여쓰기
# (1193/1247) 쿼리 검색 중: 맞춤법 프로포즈 프러포즈 외래어표현
# (1194/1247) 쿼리 검색 중: 관형사 '한'의 띄어쓰기, '한 번'의 맞춤법
# (1195/1247) 쿼리 검색 중: 중이적 의미 문장 어문규정 맞춤법 오류 수정 이유
# (1196/1247) 쿼리 검색 중: 관용어 이야기거리 어근 활용 두음법칙
# (1197/1247) 쿼리 검색 중: 의존명사 수북히 수북이 부사어 두음법칙
# (1198/1247) 쿼리 검색 중: 의존명사 코코넛 껍질 두음법칙
# (1199/1247) 쿼리 검색 중: 의존명사 만하다 부사격조사 생략 가능성 어문규정
# (1200/1247) 쿼리 검색 중: 1 대 1 대응 관계 문장부호
# (1201/1247) 쿼리 검색 중: 의존명사 짐작 명사구 어근 '-게' '-케' 음운변동
# (1202/1247) 쿼리 검색 중: 표기 원칙 어문규정 맞춤법
# (1203/1247) 쿼리 검색 중: 의존명사 율 률 한글맞춤법
# (1204/1247) 쿼리 검색 중: 맞춤법 띄어쓰기 숫자와 의존명사 금액
# (1205/1247) 쿼리 검색 중: 의존명사 날 나 날이 어근 두음법칙
# (1206/1247) 쿼리 검색 중: 의문문 종결어미 '-니' 활용, 간접화행 표현, 존댓말 어미 '-어요' 결합
# (1207/1247) 쿼리 검색 중: 의존명사 밴드 뺀드 한글 맞춤법
# (1208/1247) 쿼리 검색 중: 의존명사 열세째 띄어쓰기 숫자 띄어쓰기
# (1209/1247) 쿼리 검색 중: 의존명사 캘린더 캘린다 외래어표기법
# (1210/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성, 서술어 어미 활용, 형용사 활용
# (1211/1247) 쿼리 검색 중: 조사 생략 가능성 접속 표현 어문규정
# (1212/1247) 쿼리 검색 중: 어휘 선택 표준어 크레딧 크레디트
# (1213/1247) 쿼리 검색 중: 연도 표기 숫자 한글화 표준어 규정
# (1214/1247) 쿼리 검색 중: 관형격 조사 '의' 중복 '의의' 생략, 관형격 조사 중복 표현, 관형격 조사 '의' 생략 규정
# (1215/1247) 쿼리 검색 중: 부사 '뒤집어엎어' 불필요한 중복 어근 결합
# (1216/1247) 쿼리 검색 중: 표준어 표기 원칙 두음법칙
# (1217/1247) 쿼리 검색 중: 주책 주착 두음법칙
# (1218/1247) 쿼리 검색 중: 관형격 조사 '에'의 올바른 사용, 명사 '브랜드'의 수식 구조, 서술격 조사 '에요'의 활용
# (1219/1247) 쿼리 검색 중: 숫자 표기 한글 숫자 표기 규정
# (1220/1247) 쿼리 검색 중: 의존명사 '의' 띄어쓰기
# (1221/1247) 쿼리 검색 중: 의존명사 좀 보조사 어미 생략
# (1222/1247) 쿼리 검색 중: 날짜 표기 숫자 한글화
# (1223/1247) 쿼리 검색 중: 맞춤법 띄어쓰기 붙여쓰기
# (1224/1247) 쿼리 검색 중: < > 표준어 표기법
# (1225/1247) 쿼리 검색 중: 조사 생략 어미 연결 붙여쓰기
# (1226/1247) 쿼리 검색 중: 관형격 조사 '의' 생략 가능성 어미 활용
# (1227/1247) 쿼리 검색 중: 부사 반듯이 반듯이맞춤법
# (1228/1247) 쿼리 검색 중: 의존명사 신 씬 영화 용어
# (1229/1247) 쿼리 검색 중: 의존명사 '꼿꼿' 형태 표기
# (1230/1247) 쿼리 검색 중: 맞춤법 '-을껄' 어미 활용 표준어 규정
# (1231/1247) 쿼리 검색 중: 의존명사 셔틀버스 셔틀뻐스 두음법칙
# (1232/1247) 쿼리 검색 중: 백스테이지 백스테이쥐 외래어 표기법
# (1233/1247) 쿼리 검색 중: 조사 '뻔하다'의 활용, 부정확한 연결 어미, '하마터면'의 문법적 쓰임
# (1234/1247) 쿼리 검색 중: 의존명사 필러 피러 두음법칙
# (1235/1247) 쿼리 검색 중: 문장 부정문 표현 한 걸음 한 걸음 띄어쓰기
# (1236/1247) 쿼리 검색 중: 넉씨 넋씨 표준어 규정
# (1237/1247) 쿼리 검색 중: 의문문 문장부호 이유
# (1238/1247) 쿼리 검색 중: 의존명사 값 값의 한글 맞춤법 최고값 최곳값
# (1239/1247) 쿼리 검색 중: 의존명사 브라우닝 표기원칙 외래어표기법
# (1240/1247) 쿼리 검색 중: 의존명사 순서 수사 한자어 차이
# (1241/1247) 쿼리 검색 중: 문장부호 쉼표 생략 이유 문장부호 사용 규정
# (1242/1247) 쿼리 검색 중: 의존명사 먹기 동사 활용 어간 어미
# (1243/1247) 쿼리 검색 중: 문장 어문규범 위배 부분 수정 이유
# (1244/1247) 쿼리 검색 중: 의존명사 시간 명사구 띄어쓰기
# (1245/1247) 쿼리 검색 중: 동사 '잠그다' 어간 활용
# (1246/1247) 쿼리 검색 중: 외래어 표기법 영어 잉글리시
# (1247/1247) 쿼리 검색 중: 동사 연결어미 '-으려' '-으러'
#
# --- 6. 검색 결과 취합 및 저장 시작 ---
# 모든 검색이 완료되었으며, 결과가 '0715-retrieval_results.csv' 파일에 저장되었습니다.
#
# --- 최종 결과 (상위 5개) ---
#    id                                           question  \
# 0   1  "우동이 {불을/불} 것 같아 걱정이다." 가운데 올바른 것을 선택하고, 그 이유를...
# 1   2  다음 문장에서 어문 규범에 부합하지 않는 부분을 찾아 고치고, 그 이유를 설명하세요...
# 2   3  "묘비는 1670년 현종 11년에 후손인 김려와 언양 현감이 세웠다."를 올바르게 ...
# 3   4  다음 문장에서 어문 규범에 부합하지 않는 부분을 찾아 고치고, 그 이유를 설명하세요...
# 4   5  "{외출 시에는/외출시에는} 에어컨을 꼭 끕시다." 가운데 올바른 것을 선택하고, ...
#
#                                      expected_output  \
# 0  {'answer': '"우동이 불을 것 같아 걱정이다."가 옳다. \'붇다\'의 어...
# 1  {'answer': '"또한 갸름한 얼굴에 초승달 같은 눈썹, 가늘고 긴 눈, 오뚝...
# 2  {'answer': '"묘비는 현종 11년(1670년)에 후손인 김려와 언양 현감이...
# 3  {'answer': '"저장할까요 또는 취소할까요?"가 옳다. 한 문장 안에 몇 개...
# 4  {'answer': '"외출 시에는 에어컨을 꼭 끕시다."가 옳다. 여기서의 \'시...
#
#                       generated_queries  \
# 0                 ["부사 불 불이 아님 부사격 조사"]
# 1  ["의존명사 이목구비 한글맞춤법 오똑한 오똑한 코 표준어 규정"]
# 2                  ["묘비 건립 시기 표현 어문규정"]
# 3              ["저장할까요 취소할까요 맞춤법 어문규정"]
# 4               ["조사 생략 가능 여부 에어컨 명사구"]
#
#                                    retrieved_content
# 0  - ㄴ: 불이 꺼져간다., 내 힘으로 막아낸다., 어머니를 도와드린다., 그릇을 깨...
# 1  문장의 각 단어는 띄어 씀을 원칙으로 한다. \n조사는 그 앞말에 붙여 쓴다. \n...
# 2  [붙임 1] 어원은 분명하나 소리만 특이하게 변한 것은 변한 대로 적는다.  \n-...
# 3  - 베어, 베어도, 베어서 \n- 쉬어, 쉬어도, 쉬어서 \n- 저어, 저어도, 저...
# 4  - ㄱ: 지난겨울은 몹시 춥더라., 깊던 물이 얕아졌다., 그렇게 좋던가?, 그 사...
